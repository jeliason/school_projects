# %%
import numpy as np
import copy
import os
import pickle
from keras.layers import Dense
from keras.optimizers import RMSprop
from keras.models import Sequential

class QLearner():
    # load in simulator, initialize global variables
    def __init__(self,simulator,savename,**kwargs):
        # make simulator global
        self.simulator = simulator
        
        # Q learn params
        self.explore_val = 1
        self.explore_decay = 0.99
        self.num_episodes = 500        
        self.gamma = 1
        self.episode_update = 10
        
        if "gamma" in kwargs:   
            self.gamma = args['gamma']
        if 'explore_val' in kwargs:
            self.explore_val = kwargs['explore_val']
        if 'explore_decay' in kwargs:
            self.explore_decay = kwargs['explore_decay']
        if 'num_episodes' in kwargs:
            self.num_episodes = kwargs['num_episodes']
        if 'episode_update' in kwargs:
            self.episode_update = kwargs['episode_update']
            
        # other training variables
        self.num_actions = self.simulator.action_space.n
        state = self.simulator.reset()    
        self.state_dim = np.size(state)
        self.training_reward = []
        
        # setup memory params
        self.memory = []
        if 'memory_length' in kwargs:
            self.memory_length = kwargs['memory_length']
        if 'replay_length' in kwargs:
            self.replay_length = kwargs['replay_length']
        if 'memory_start' in kwargs:
            self.memory_start = kwargs['memory_start']
        
        ### initialize logs ###
        # create text file for training log
        self.logname = 'training_logs/' + savename + '.txt'
        self.reward_logname = 'reward_logs/' + savename + '.txt'
        self.weight_name = 'saved_model_weights/' + savename + '.pkl' 
        self.model_name = 'models/' + savename + '.json'

        self.init_log(self.logname)
        self.init_log(self.reward_logname)
        self.init_log(self.weight_name)
        self.init_log(self.model_name)
     
    ##### logging functions #####
    def init_log(self,logname):
        # delete log if old version exists
        if os.path.exists(logname): 
            os.remove(logname)
            
    def update_log(self,logname,update):
        if type(update) == str:
            logfile = open(logname, "a")
            logfile.write(update)
            logfile.close() 
        else:
            weights = []
            if os.path.exists(logname):
                with open(logname,'rb') as rfp: 
                    weights = pickle.load(rfp)
            weights.append(update)

            with open(logname,'wb') as wfp:
                pickle.dump(weights, wfp)
    
    ##### functions for creating / updating Q #####
    def initialize_Q(self,**kwargs):
        # default parameters for network
        layer_sizes = [10,10]      # two hidden layers, 10 units each, by default
        activation = 'relu'
        if 'layer_sizes' in kwargs:
            layer_sizes = kwargs['layer_sizes']
        if 'activation' in kwargs:
            activation = kwargs['activation']

        # default parameters for optimizer - reset by hand
        loss = 'mse'
        lr = 10**(-2)
        if 'alpha' in kwargs:
            lr = kwargs['alpha']
        optimizer = RMSprop(lr = lr)        

        # input / output sizes of network
        input_dim = self.state_dim
        output_dim = self.num_actions

        # build model based on parameters
        self.model = Sequential()

        # add input layer
        self.model.add(Dense(layer_sizes[0], input_dim=input_dim, activation=activation))

        # add hidden layers
        for U in layer_sizes[1:]:
            self.model.add(Dense(U,activation=activation))

        # add output layer
        self.model.add(Dense(output_dim, activation='linear'))

        # chose optimizer and its associated parameters
        self.model.compile(loss=loss, optimizer=optimizer)
        
        # initialize Q
        self.Q = self.model.predict
        
        # since its easy to save models with keras / tensorflow, save to file
        model_json = self.model.to_json()
        with open(self.model_name, "w") as json_file:
            json_file.write(model_json)

    # update Q function
    def update_Q(self):        
        # generate q_values based on most recent Q
        q_vals = []
        states = []
        for i in range(len(self.memory)):    
            # get episode_data
            episode_data = self.memory[i]
            
            # loop over episode data and create input/output pairs
            for j in range(len(episode_data)):
                # get next sample of episode
                sample = episode_data[j]
            
                # strip sample for parts
                state = sample[0]
                next_state = sample[1]
                action = sample[2]
                reward = sample[3]
                done = sample[4]

                ### for cartpole only - check if done, and alter reward to improve learning ###
                done,reward = self.check_done(done,reward)

                # compute and store q value
                q = reward 
                if done == False:
                    qs = self.Q(next_state)
                    q += self.gamma*np.max(qs)

                # clamp all other models to their current values for this input/output pair
                q_update = self.Q(state).flatten()
                q_update[action] = q
                q_vals.append(q_update)
                states.append(state.T)
            
        # convert lists to numpy arrays for regressor
        s_in = np.array(states).T
        q_vals = np.array(q_vals).T
        s_in = s_in[0,:,:]
                            
        # take descent step
        num_pts = s_in.shape[1]
        self.model.fit(x=s_in.T,y=q_vals.T,batch_size=num_pts, epochs=1,verbose = 0)
        
        # update Q based on regressor updates
        self.Q = self.model.predict
        
    ##### functions for adjusting replay memory #####
    # update memory - add sample to list, remove oldest samples 
    def update_memory(self,episode_data):
        # add most recent trial data to memory
        self.memory.append(episode_data)

        # clip memory if it gets too long    
        num_episodes = len(self.memory)
        if num_episodes >= self.memory_length:    
            num_delete = num_episodes - self.memory_length
            self.memory[:num_delete] = []
    
    ##### Q Learning functionality #####
    # special function to check done
    def check_done(self,done,reward):
        if done == True:
            reward = -100
        return done,reward
    
    # state normalizer
    def state_normalizer(self,states):
        states = np.array(states)[np.newaxis,:]
        return states
    
    # choose next action
    def choose_action(self,state):
        # pick action at random
        p = np.random.rand(1)   
        action = np.random.randint(self.num_actions)
            
        # pick action based on exploiting
        qs = self.Q(state) 
        if p > self.explore_val:
            action = np.argmax(qs)
        return action
    
    # main training function
    def train(self,**kwargs):        
        ### start main Q-learning loop ###
        for n in range(self.num_episodes): 
            # pick this episode's starting position - randomly initialize from f_system
            state = self.simulator.reset()    
            state = self.state_normalizer(state)
            total_episode_reward = 0
            done = False
            
            # get out exploit parameter for this episode
            if self.explore_val > 0.01:
                self.explore_val *= self.explore_decay
                    
            # run episode
            step = 0
            episode_data = []
            while done == False and step < 500:    
                # choose next action
                action = self.choose_action(state)
    
                # transition to next state, get associated reward
                next_state,reward,done,info = self.simulator.step(action)  
                next_state = self.state_normalizer(next_state)
                
                # store data for transition after episode ends
                episode_data.append([state,next_state,action,reward,done])

                # update total reward from this episode
                total_episode_reward+=reward
                state = copy.deepcopy(next_state)
                step+=1
            
            # update memory with this episode's data
            self.update_memory(episode_data)
            
            # update Q function
            if np.mod(n,self.episode_update) == 0:
                self.update_Q()  
                  
            ### print out updates ###
            update = 'training episode ' + str(n+1) +  ' of ' + str(self.num_episodes) + ' complete, ' +  ' explore val = ' + str(np.round(self.explore_val,3)) + ', episode reward = ' + str(np.round(total_episode_reward,2)) 

            self.update_log(self.logname,update + '\n')
            print (update)

            update = str(total_episode_reward) + '\n'
            self.update_log(self.reward_logname,update)

            ### store this episode's computation time and training reward history
            self.training_reward.append(total_episode_reward)

            # save latest weights from this episode 
            update = self.model.get_weights()
            self.update_log(self.weight_name,update)
            
        ### save weights ###
        update = 'q-learning algorithm complete'
        self.update_log(self.logname,update + '\n')
        print (update)
# Out:
# /home/joele119/Desktop/rl_env/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# # Run test

# %%
# imports
import gym

# savename
savename = 'cartpole_experiment_1'

# initialize simulator
cartpole = gym.make('CartPole-v1') 

# initialize Q Learn process
num_episodes = 1000
explore_decay = 1
explore_val = 0.01

# initialize memory
episode_update = 1
memory_length = 10

# load into instance of learner
demo = QLearner(cartpole,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,episode_update=episode_update)

# initialize Q function
layer_sizes = [50,50]
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# /home/joele119/Desktop/ml_class/Reinforce_hw_2_w_examples/gym/gym/__init__.py:22: UserWarning: DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.
#   warnings.warn('DEPRECATION WARNING: to improve load times, gym no longer automatically loads gym.spaces. Please run "import gym.spaces" to load gym.spaces on your own. This warning will turn into an error in a future version of gym.')

# %%
demo.train()
# Out:
# training episode 1 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 2 of 1000 complete,  explore val = 0.01, episode reward = 438.0
# training episode 3 of 1000 complete,  explore val = 0.01, episode reward = 34.0
# training episode 4 of 1000 complete,  explore val = 0.01, episode reward = 74.0
# training episode 5 of 1000 complete,  explore val = 0.01, episode reward = 37.0
# training episode 6 of 1000 complete,  explore val = 0.01, episode reward = 37.0
# training episode 7 of 1000 complete,  explore val = 0.01, episode reward = 115.0
# training episode 8 of 1000 complete,  explore val = 0.01, episode reward = 42.0
# training episode 9 of 1000 complete,  explore val = 0.01, episode reward = 47.0
# training episode 10 of 1000 complete,  explore val = 0.01, episode reward = 14.0
# training episode 11 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 12 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 13 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 14 of 1000 complete,  explore val = 0.01, episode reward = 26.0
# training episode 15 of 1000 complete,  explore val = 0.01, episode reward = 40.0
# training episode 16 of 1000 complete,  explore val = 0.01, episode reward = 29.0
# training episode 17 of 1000 complete,  explore val = 0.01, episode reward = 50.0
# training episode 18 of 1000 complete,  explore val = 0.01, episode reward = 83.0
# training episode 19 of 1000 complete,  explore val = 0.01, episode reward = 64.0
# training episode 20 of 1000 complete,  explore val = 0.01, episode reward = 122.0
# training episode 21 of 1000 complete,  explore val = 0.01, episode reward = 90.0
# training episode 22 of 1000 complete,  explore val = 0.01, episode reward = 35.0
# training episode 23 of 1000 complete,  explore val = 0.01, episode reward = 63.0
# training episode 24 of 1000 complete,  explore val = 0.01, episode reward = 208.0
# training episode 25 of 1000 complete,  explore val = 0.01, episode reward = 121.0
# training episode 26 of 1000 complete,  explore val = 0.01, episode reward = 34.0
# training episode 27 of 1000 complete,  explore val = 0.01, episode reward = 101.0
# training episode 28 of 1000 complete,  explore val = 0.01, episode reward = 31.0
# training episode 29 of 1000 complete,  explore val = 0.01, episode reward = 25.0
# training episode 30 of 1000 complete,  explore val = 0.01, episode reward = 24.0
# training episode 31 of 1000 complete,  explore val = 0.01, episode reward = 25.0
# training episode 32 of 1000 complete,  explore val = 0.01, episode reward = 67.0
# training episode 33 of 1000 complete,  explore val = 0.01, episode reward = 55.0
# training episode 34 of 1000 complete,  explore val = 0.01, episode reward = 51.0
# training episode 35 of 1000 complete,  explore val = 0.01, episode reward = 54.0
# training episode 36 of 1000 complete,  explore val = 0.01, episode reward = 60.0
# training episode 37 of 1000 complete,  explore val = 0.01, episode reward = 50.0
# training episode 38 of 1000 complete,  explore val = 0.01, episode reward = 57.0
# training episode 39 of 1000 complete,  explore val = 0.01, episode reward = 60.0
# training episode 40 of 1000 complete,  explore val = 0.01, episode reward = 41.0
# training episode 41 of 1000 complete,  explore val = 0.01, episode reward = 57.0
# training episode 42 of 1000 complete,  explore val = 0.01, episode reward = 114.0
# training episode 43 of 1000 complete,  explore val = 0.01, episode reward = 48.0
# training episode 44 of 1000 complete,  explore val = 0.01, episode reward = 78.0
# training episode 45 of 1000 complete,  explore val = 0.01, episode reward = 16.0
# training episode 46 of 1000 complete,  explore val = 0.01, episode reward = 40.0
# training episode 47 of 1000 complete,  explore val = 0.01, episode reward = 26.0
# training episode 48 of 1000 complete,  explore val = 0.01, episode reward = 24.0
# training episode 49 of 1000 complete,  explore val = 0.01, episode reward = 33.0
# training episode 50 of 1000 complete,  explore val = 0.01, episode reward = 27.0
# training episode 51 of 1000 complete,  explore val = 0.01, episode reward = 38.0
# training episode 52 of 1000 complete,  explore val = 0.01, episode reward = 27.0
# training episode 53 of 1000 complete,  explore val = 0.01, episode reward = 25.0
# training episode 54 of 1000 complete,  explore val = 0.01, episode reward = 33.0
# training episode 55 of 1000 complete,  explore val = 0.01, episode reward = 127.0
# training episode 56 of 1000 complete,  explore val = 0.01, episode reward = 16.0
# training episode 57 of 1000 complete,  explore val = 0.01, episode reward = 57.0
# training episode 58 of 1000 complete,  explore val = 0.01, episode reward = 177.0
# training episode 59 of 1000 complete,  explore val = 0.01, episode reward = 300.0
# training episode 60 of 1000 complete,  explore val = 0.01, episode reward = 116.0
# training episode 61 of 1000 complete,  explore val = 0.01, episode reward = 77.0
# training episode 62 of 1000 complete,  explore val = 0.01, episode reward = 36.0
# training episode 63 of 1000 complete,  explore val = 0.01, episode reward = 52.0
# training episode 64 of 1000 complete,  explore val = 0.01, episode reward = 37.0
# training episode 65 of 1000 complete,  explore val = 0.01, episode reward = 27.0
# training episode 66 of 1000 complete,  explore val = 0.01, episode reward = 156.0
# training episode 67 of 1000 complete,  explore val = 0.01, episode reward = 56.0
# training episode 68 of 1000 complete,  explore val = 0.01, episode reward = 72.0
# training episode 69 of 1000 complete,  explore val = 0.01, episode reward = 64.0
# training episode 70 of 1000 complete,  explore val = 0.01, episode reward = 58.0
# training episode 71 of 1000 complete,  explore val = 0.01, episode reward = 71.0
# training episode 72 of 1000 complete,  explore val = 0.01, episode reward = 96.0
# training episode 73 of 1000 complete,  explore val = 0.01, episode reward = 40.0
# training episode 74 of 1000 complete,  explore val = 0.01, episode reward = 58.0
# training episode 75 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 76 of 1000 complete,  explore val = 0.01, episode reward = 190.0
# training episode 77 of 1000 complete,  explore val = 0.01, episode reward = 149.0
# training episode 78 of 1000 complete,  explore val = 0.01, episode reward = 84.0
# training episode 79 of 1000 complete,  explore val = 0.01, episode reward = 231.0
# training episode 80 of 1000 complete,  explore val = 0.01, episode reward = 75.0
# training episode 81 of 1000 complete,  explore val = 0.01, episode reward = 405.0
# training episode 82 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 83 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 84 of 1000 complete,  explore val = 0.01, episode reward = 441.0
# training episode 85 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 86 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 87 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 88 of 1000 complete,  explore val = 0.01, episode reward = 16.0
# training episode 89 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 90 of 1000 complete,  explore val = 0.01, episode reward = 14.0
# training episode 91 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 92 of 1000 complete,  explore val = 0.01, episode reward = 16.0
# training episode 93 of 1000 complete,  explore val = 0.01, episode reward = 90.0
# training episode 94 of 1000 complete,  explore val = 0.01, episode reward = 19.0
# training episode 95 of 1000 complete,  explore val = 0.01, episode reward = 41.0
# training episode 96 of 1000 complete,  explore val = 0.01, episode reward = 31.0
# training episode 97 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 98 of 1000 complete,  explore val = 0.01, episode reward = 154.0
# training episode 99 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 100 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 101 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 102 of 1000 complete,  explore val = 0.01, episode reward = 27.0
# training episode 103 of 1000 complete,  explore val = 0.01, episode reward = 68.0
# training episode 104 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 105 of 1000 complete,  explore val = 0.01, episode reward = 23.0
# training episode 106 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 107 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 108 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 109 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 110 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 111 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 112 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 113 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 114 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 115 of 1000 complete,  explore val = 0.01, episode reward = 398.0
# training episode 116 of 1000 complete,  explore val = 0.01, episode reward = 169.0
# training episode 117 of 1000 complete,  explore val = 0.01, episode reward = 20.0
# training episode 118 of 1000 complete,  explore val = 0.01, episode reward = 131.0
# training episode 119 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 120 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 121 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 122 of 1000 complete,  explore val = 0.01, episode reward = 487.0
# training episode 123 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 124 of 1000 complete,  explore val = 0.01, episode reward = 352.0
# training episode 125 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 126 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 127 of 1000 complete,  explore val = 0.01, episode reward = 19.0
# training episode 128 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 129 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 130 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 131 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 132 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 133 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 134 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 135 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 136 of 1000 complete,  explore val = 0.01, episode reward = 31.0
# training episode 137 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 138 of 1000 complete,  explore val = 0.01, episode reward = 99.0
# training episode 139 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 140 of 1000 complete,  explore val = 0.01, episode reward = 404.0
# training episode 141 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 142 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 143 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 144 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 145 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 146 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 147 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 148 of 1000 complete,  explore val = 0.01, episode reward = 16.0
# training episode 149 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 150 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 151 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 152 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 153 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 154 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 155 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 156 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 157 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 158 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 159 of 1000 complete,  explore val = 0.01, episode reward = 37.0
# training episode 160 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 161 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 162 of 1000 complete,  explore val = 0.01, episode reward = 23.0
# training episode 163 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 164 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 165 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 166 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 167 of 1000 complete,  explore val = 0.01, episode reward = 25.0
# training episode 168 of 1000 complete,  explore val = 0.01, episode reward = 269.0
# training episode 169 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 170 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 171 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 172 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 173 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 174 of 1000 complete,  explore val = 0.01, episode reward = 50.0
# training episode 175 of 1000 complete,  explore val = 0.01, episode reward = 408.0
# training episode 176 of 1000 complete,  explore val = 0.01, episode reward = 116.0
# training episode 177 of 1000 complete,  explore val = 0.01, episode reward = 426.0
# training episode 178 of 1000 complete,  explore val = 0.01, episode reward = 332.0
# training episode 179 of 1000 complete,  explore val = 0.01, episode reward = 305.0
# training episode 180 of 1000 complete,  explore val = 0.01, episode reward = 143.0
# training episode 181 of 1000 complete,  explore val = 0.01, episode reward = 200.0
# training episode 182 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 183 of 1000 complete,  explore val = 0.01, episode reward = 275.0
# training episode 184 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 185 of 1000 complete,  explore val = 0.01, episode reward = 384.0
# training episode 186 of 1000 complete,  explore val = 0.01, episode reward = 375.0
# training episode 187 of 1000 complete,  explore val = 0.01, episode reward = 264.0
# training episode 188 of 1000 complete,  explore val = 0.01, episode reward = 252.0
# training episode 189 of 1000 complete,  explore val = 0.01, episode reward = 233.0
# training episode 190 of 1000 complete,  explore val = 0.01, episode reward = 202.0
# training episode 191 of 1000 complete,  explore val = 0.01, episode reward = 244.0
# training episode 192 of 1000 complete,  explore val = 0.01, episode reward = 276.0
# training episode 193 of 1000 complete,  explore val = 0.01, episode reward = 310.0
# training episode 194 of 1000 complete,  explore val = 0.01, episode reward = 331.0
# training episode 195 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 196 of 1000 complete,  explore val = 0.01, episode reward = 456.0
# training episode 197 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 198 of 1000 complete,  explore val = 0.01, episode reward = 485.0
# training episode 199 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 200 of 1000 complete,  explore val = 0.01, episode reward = 323.0
# training episode 201 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 202 of 1000 complete,  explore val = 0.01, episode reward = 257.0
# training episode 203 of 1000 complete,  explore val = 0.01, episode reward = 21.0
# training episode 204 of 1000 complete,  explore val = 0.01, episode reward = 209.0
# training episode 205 of 1000 complete,  explore val = 0.01, episode reward = 475.0
# training episode 206 of 1000 complete,  explore val = 0.01, episode reward = 195.0
# training episode 207 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 208 of 1000 complete,  explore val = 0.01, episode reward = 189.0
# training episode 209 of 1000 complete,  explore val = 0.01, episode reward = 302.0
# training episode 210 of 1000 complete,  explore val = 0.01, episode reward = 196.0
# training episode 211 of 1000 complete,  explore val = 0.01, episode reward = 219.0
# training episode 212 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 213 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 214 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 215 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 216 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 217 of 1000 complete,  explore val = 0.01, episode reward = 14.0
# training episode 218 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 219 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 220 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 221 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 222 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 223 of 1000 complete,  explore val = 0.01, episode reward = 14.0
# training episode 224 of 1000 complete,  explore val = 0.01, episode reward = 14.0
# training episode 225 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 226 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 227 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 228 of 1000 complete,  explore val = 0.01, episode reward = 28.0
# training episode 229 of 1000 complete,  explore val = 0.01, episode reward = 242.0
# training episode 230 of 1000 complete,  explore val = 0.01, episode reward = 268.0
# training episode 231 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 232 of 1000 complete,  explore val = 0.01, episode reward = 174.0
# training episode 233 of 1000 complete,  explore val = 0.01, episode reward = 218.0
# training episode 234 of 1000 complete,  explore val = 0.01, episode reward = 22.0
# training episode 235 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 236 of 1000 complete,  explore val = 0.01, episode reward = 165.0
# training episode 237 of 1000 complete,  explore val = 0.01, episode reward = 22.0
# training episode 238 of 1000 complete,  explore val = 0.01, episode reward = 204.0
# training episode 239 of 1000 complete,  explore val = 0.01, episode reward = 229.0
# training episode 240 of 1000 complete,  explore val = 0.01, episode reward = 294.0
# training episode 241 of 1000 complete,  explore val = 0.01, episode reward = 315.0
# training episode 242 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 243 of 1000 complete,  explore val = 0.01, episode reward = 458.0
# training episode 244 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 245 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 246 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 247 of 1000 complete,  explore val = 0.01, episode reward = 107.0
# training episode 248 of 1000 complete,  explore val = 0.01, episode reward = 417.0
# training episode 249 of 1000 complete,  explore val = 0.01, episode reward = 363.0
# training episode 250 of 1000 complete,  explore val = 0.01, episode reward = 376.0
# training episode 251 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 252 of 1000 complete,  explore val = 0.01, episode reward = 319.0
# training episode 253 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 254 of 1000 complete,  explore val = 0.01, episode reward = 315.0
# training episode 255 of 1000 complete,  explore val = 0.01, episode reward = 380.0
# training episode 256 of 1000 complete,  explore val = 0.01, episode reward = 278.0
# training episode 257 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 258 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 259 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 260 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 261 of 1000 complete,  explore val = 0.01, episode reward = 289.0
# training episode 262 of 1000 complete,  explore val = 0.01, episode reward = 387.0
# training episode 263 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 264 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 265 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 266 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 267 of 1000 complete,  explore val = 0.01, episode reward = 187.0
# training episode 268 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 269 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 270 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 271 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 272 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 273 of 1000 complete,  explore val = 0.01, episode reward = 21.0
# training episode 274 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 275 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 276 of 1000 complete,  explore val = 0.01, episode reward = 343.0
# training episode 277 of 1000 complete,  explore val = 0.01, episode reward = 120.0
# training episode 278 of 1000 complete,  explore val = 0.01, episode reward = 324.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-cf8c7d3d2c01> in <module>()
# ----> 1 demo.train()
#
# <ipython-input-1-78bd9c0df126> in train(self, **kwargs)
#     246             # update Q function
#     247             if np.mod(n,self.episode_update) == 0:
# --> 248                 self.update_Q()
#     249
#     250             ### print out updates ###
#
# <ipython-input-1-78bd9c0df126> in update_Q(self)
#     151                 q = reward
#     152                 if done == False:
# --> 153                     qs = self.Q(next_state)
#     154                     q += self.gamma*np.max(qs)
#     155
#
# ~/Desktop/rl_env/lib/python3.5/site-packages/keras/models.py in predict(self, x, batch_size, verbose, steps)
#    1062             self.build()
#    1063         return self.model.predict(x, batch_size=batch_size, verbose=verbose,
# -> 1064                                   steps=steps)
#    1065
#    1066     def predict_on_batch(self, x):
#
# ~/Desktop/rl_env/lib/python3.5/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1833         f = self.predict_function
#    1834         return self._predict_loop(f, ins, batch_size=batch_size,
# -> 1835                                   verbose=verbose, steps=steps)
#    1836
#    1837     def train_on_batch(self, x, y,
#
# ~/Desktop/rl_env/lib/python3.5/site-packages/keras/engine/training.py in _predict_loop(self, f, ins, batch_size, verbose, steps)
#    1329                     ins_batch[i] = ins_batch[i].toarray()
#    1330
# -> 1331                 batch_outs = f(ins_batch)
#    1332                 if not isinstance(batch_outs, list):
#    1333                     batch_outs = [batch_outs]
#
# ~/Desktop/rl_env/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2480         session = get_session()
#    2481         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2482                               **self.session_kwargs)
#    2483         return updated[:len(self.outputs)]
#    2484
#
# ~/Desktop/rl_env/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/Desktop/rl_env/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1068     feed_handles = {}
#    1069     if feed_dict:
# -> 1070       feed_dict = nest.flatten_dict_items(feed_dict)
#    1071       for feed, feed_val in feed_dict.items():
#    1072         for subfeed, subfeed_val in _feed_fn(feed, feed_val):
#
# ~/Desktop/rl_env/lib/python3.5/site-packages/tensorflow/python/util/nest.py in flatten_dict_items(dictionary)
#     218   flat_dictionary = {}
#     219   for i, v in _six.iteritems(dictionary):
# --> 220     if not is_sequence(i):
#     221       if i in flat_dictionary:
#     222         raise ValueError(
#
# ~/Desktop/rl_env/lib/python3.5/site-packages/tensorflow/python/util/nest.py in is_sequence(seq)
#     114     dict.
#     115   """
# --> 116   return _pywrap_tensorflow.IsSequence(seq)
#     117
#     118
#
# KeyboardInterrupt:

# %% [markdown]
# # plot total episode reward history

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_reward_history(logname,**kwargs):
    # load in total episode reward history
    data = np.loadtxt(logname)
    ave = [data[v] for v in range(100)]
    
    for i in range(0,np.size(data)-100):
        m = np.mean(data[i:i+100])
        ave.append(m)
    
    # create figure
    fig = plt.figure(figsize = (12,8))
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,1,2)

    # plot total reward history
    start = 0
    if 'start' in kwargs:
        start = kwargs['start']
    ax1.plot(data[start:])
    ax1.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax1.set_ylabel('total reward',fontsize = 13)
    
    ax2.plot(ave[start:],linewidth=3)
    ax2.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax2.set_ylabel('ave total reward',fontsize=13)
    plt.show()

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plot_reward_history(reward_logname)

# %% [markdown]
# # produce animation of validation run

# %%
# load in weights
infile = demo.weight_name
with open(infile, 'rb') as in_strm:
    datastruct = pickle.load(in_strm)
