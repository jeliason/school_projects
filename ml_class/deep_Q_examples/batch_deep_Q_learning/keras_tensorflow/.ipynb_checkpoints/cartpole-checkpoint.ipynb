# %%
import numpy as np
import copy
import os
import pickle
from keras.layers import Dense
from keras.optimizers import RMSprop
from keras.models import Sequential

class QLearner():
    # load in simulator, initialize global variables
    def __init__(self,simulator,savename,**kwargs):
        # make simulator global
        self.simulator = simulator
        
        # Q learn params
        self.explore_val = 1
        self.explore_decay = 0.99
        self.num_episodes = 500        
        self.gamma = 1
        self.episode_update = 10
        
        if "gamma" in kwargs:   
            self.gamma = args['gamma']
        if 'explore_val' in kwargs:
            self.explore_val = kwargs['explore_val']
        if 'explore_decay' in kwargs:
            self.explore_decay = kwargs['explore_decay']
        if 'num_episodes' in kwargs:
            self.num_episodes = kwargs['num_episodes']
        if 'episode_update' in kwargs:
            self.episode_update = kwargs['episode_update']
            
        # other training variables
        self.num_actions = self.simulator.action_space.n
        state = self.simulator.reset()    
        self.state_dim = np.size(state)
        self.training_reward = []
        
        # setup memory params
        self.memory = []
        if 'memory_length' in kwargs:
            self.memory_length = kwargs['memory_length']
        if 'replay_length' in kwargs:
            self.replay_length = kwargs['replay_length']
        if 'memory_start' in kwargs:
            self.memory_start = kwargs['memory_start']
        
        ### initialize logs ###
        # create text file for training log
        self.logname = 'training_logs/' + savename + '.txt'
        self.reward_logname = 'reward_logs/' + savename + '.txt'
        self.weight_name = 'saved_model_weights/' + savename + '.pkl' 
        self.model_name = 'models/' + savename + '.json'

        self.init_log(self.logname)
        self.init_log(self.reward_logname)
        self.init_log(self.weight_name)
        self.init_log(self.model_name)
     
    ##### logging functions #####
    def init_log(self,logname):
        # delete log if old version exists
        if os.path.exists(logname): 
            os.remove(logname)
            
    def update_log(self,logname,update):
        if type(update) == str:
            logfile = open(logname, "a")
            logfile.write(update)
            logfile.close() 
        else:
            weights = []
            if os.path.exists(logname):
                with open(logname,'rb') as rfp: 
                    weights = pickle.load(rfp)
            weights.append(update)

            with open(logname,'wb') as wfp:
                pickle.dump(weights, wfp)
    
    ##### functions for creating / updating Q #####
    def initialize_Q(self,**kwargs):
        # default parameters for network
        layer_sizes = [10,10]      # two hidden layers, 10 units each, by default
        activation = 'relu'
        if 'layer_sizes' in kwargs:
            layer_sizes = kwargs['layer_sizes']
        if 'activation' in kwargs:
            activation = kwargs['activation']

        # default parameters for optimizer - reset by hand
        loss = 'mse'
        lr = 10**(-2)
        if 'alpha' in kwargs:
            lr = kwargs['alpha']
        optimizer = RMSprop(lr = lr)        

        # input / output sizes of network
        input_dim = self.state_dim
        output_dim = self.num_actions

        # build model based on parameters
        self.model = Sequential()

        # add input layer
        self.model.add(Dense(layer_sizes[0], input_dim=input_dim, activation=activation))

        # add hidden layers
        for U in layer_sizes[1:]:
            self.model.add(Dense(U,activation=activation))

        # add output layer
        self.model.add(Dense(output_dim, activation='linear'))

        # chose optimizer and its associated parameters
        self.model.compile(loss=loss, optimizer=optimizer)
        
        # initialize Q
        self.Q = self.model.predict
        
        # since its easy to save models with keras / tensorflow, save to file
        model_json = self.model.to_json()
        with open(self.model_name, "w") as json_file:
            json_file.write(model_json)

    # update Q function
    def update_Q(self):        
        # generate q_values based on most recent Q
        q_vals = []
        states = []
        for i in range(len(self.memory)):    
            # get episode_data
            episode_data = self.memory[i]
            
            # loop over episode data and create input/output pairs
            for j in range(len(episode_data)):
                # get next sample of episode
                sample = episode_data[j]
            
                # strip sample for parts
                state = sample[0]
                next_state = sample[1]
                action = sample[2]
                reward = sample[3]
                done = sample[4]

                ### for cartpole only - check if done, and alter reward to improve learning ###
                done,reward = self.check_done(done,reward)

                # compute and store q value
                q = reward 
                if done == False:
                    qs = self.Q(next_state)
                    q += self.gamma*np.max(qs)

                # clamp all other models to their current values for this input/output pair
                q_update = self.Q(state).flatten()
                q_update[action] = q
                q_vals.append(q_update)
                states.append(state.T)
            
        # convert lists to numpy arrays for regressor
        s_in = np.array(states).T
        q_vals = np.array(q_vals).T
        s_in = s_in[0,:,:]
                            
        # take descent step
        num_pts = s_in.shape[1]
        self.model.fit(x=s_in.T,y=q_vals.T,batch_size=num_pts, epochs=1,verbose = 0)
        
        # update Q based on regressor updates
        self.Q = self.model.predict
        
    ##### functions for adjusting replay memory #####
    # update memory - add sample to list, remove oldest samples 
    def update_memory(self,episode_data):
        # add most recent trial data to memory
        self.memory.append(episode_data)

        # clip memory if it gets too long    
        num_episodes = len(self.memory)
        if num_episodes >= self.memory_length:    
            num_delete = num_episodes - self.memory_length
            self.memory[:num_delete] = []
    
    ##### Q Learning functionality #####
    # special function to check done
    def check_done(self,done,reward):
        if done == True:
            reward = -100
        return done,reward
    
    # state normalizer
    def state_normalizer(self,states):
        states = np.array(states)[np.newaxis,:]
        return states
    
    # choose next action
    def choose_action(self,state):
        # pick action at random
        p = np.random.rand(1)   
        action = np.random.randint(self.num_actions)
            
        # pick action based on exploiting
        qs = self.Q(state) 
        if p > self.explore_val:
            action = np.argmax(qs)
        return action
    
    # main training function
    def train(self,**kwargs):        
        ### start main Q-learning loop ###
        for n in range(self.num_episodes): 
            # pick this episode's starting position - randomly initialize from f_system
            state = self.simulator.reset()    
            state = self.state_normalizer(state)
            total_episode_reward = 0
            done = False
            
            # get out exploit parameter for this episode
            if self.explore_val > 0.01:
                self.explore_val *= self.explore_decay
                    
            # run episode
            step = 0
            episode_data = []
            while done == False and step < 500:    
                # choose next action
                action = self.choose_action(state)
    
                # transition to next state, get associated reward
                next_state,reward,done,info = self.simulator.step(action)  
                next_state = self.state_normalizer(next_state)
                
                # store data for transition after episode ends
                episode_data.append([state,next_state,action,reward,done])

                # update total reward from this episode
                total_episode_reward+=reward
                state = copy.deepcopy(next_state)
                step+=1
            
            # update memory with this episode's data
            self.update_memory(episode_data)
            
            # update Q function
            if np.mod(n,self.episode_update) == 0:
                self.update_Q()  
                  
            ### print out updates ###
            update = 'training episode ' + str(n+1) +  ' of ' + str(self.num_episodes) + ' complete, ' +  ' explore val = ' + str(np.round(self.explore_val,3)) + ', episode reward = ' + str(np.round(total_episode_reward,2)) 

            self.update_log(self.logname,update + '\n')
            print (update)

            update = str(total_episode_reward) + '\n'
            self.update_log(self.reward_logname,update)

            ### store this episode's computation time and training reward history
            self.training_reward.append(total_episode_reward)

            # save latest weights from this episode 
            update = self.model.get_weights()
            self.update_log(self.weight_name,update)
            
        ### save weights ###
        update = 'q-learning algorithm complete'
        self.update_log(self.logname,update + '\n')
        print (update)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Run test

# %%
# imports
import gym

# savename
savename = 'cartpole_experiment_1'

# initialize simulator
cartpole = gym.make('CartPole-v1') 

# initialize Q Learn process
num_episodes = 1000
explore_decay = 1
explore_val = 0.01

# initialize memory
episode_update = 1
memory_length = 10

# load into instance of learner
demo = QLearner(cartpole,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,episode_update=episode_update)

# initialize Q function
layer_sizes = [50,50]
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
demo.train()
# Out:
# training episode 1 of 1000 complete,  explore val = 0.01, episode reward = 9.0
# training episode 2 of 1000 complete,  explore val = 0.01, episode reward = 27.0
# training episode 3 of 1000 complete,  explore val = 0.01, episode reward = 57.0
# training episode 4 of 1000 complete,  explore val = 0.01, episode reward = 41.0
# training episode 5 of 1000 complete,  explore val = 0.01, episode reward = 73.0
# training episode 6 of 1000 complete,  explore val = 0.01, episode reward = 51.0
# training episode 7 of 1000 complete,  explore val = 0.01, episode reward = 42.0
# training episode 8 of 1000 complete,  explore val = 0.01, episode reward = 38.0
# training episode 9 of 1000 complete,  explore val = 0.01, episode reward = 30.0
# training episode 10 of 1000 complete,  explore val = 0.01, episode reward = 36.0
# training episode 11 of 1000 complete,  explore val = 0.01, episode reward = 32.0
# training episode 12 of 1000 complete,  explore val = 0.01, episode reward = 38.0
# training episode 13 of 1000 complete,  explore val = 0.01, episode reward = 28.0
# training episode 14 of 1000 complete,  explore val = 0.01, episode reward = 59.0
# training episode 15 of 1000 complete,  explore val = 0.01, episode reward = 50.0
# training episode 16 of 1000 complete,  explore val = 0.01, episode reward = 44.0
# training episode 17 of 1000 complete,  explore val = 0.01, episode reward = 148.0
# training episode 18 of 1000 complete,  explore val = 0.01, episode reward = 61.0
# training episode 19 of 1000 complete,  explore val = 0.01, episode reward = 68.0
# training episode 20 of 1000 complete,  explore val = 0.01, episode reward = 69.0
# training episode 21 of 1000 complete,  explore val = 0.01, episode reward = 41.0
# training episode 22 of 1000 complete,  explore val = 0.01, episode reward = 49.0
# training episode 23 of 1000 complete,  explore val = 0.01, episode reward = 44.0
# training episode 24 of 1000 complete,  explore val = 0.01, episode reward = 37.0
# training episode 25 of 1000 complete,  explore val = 0.01, episode reward = 53.0
# training episode 26 of 1000 complete,  explore val = 0.01, episode reward = 41.0
# training episode 27 of 1000 complete,  explore val = 0.01, episode reward = 480.0
# training episode 28 of 1000 complete,  explore val = 0.01, episode reward = 59.0
# training episode 29 of 1000 complete,  explore val = 0.01, episode reward = 278.0
# training episode 30 of 1000 complete,  explore val = 0.01, episode reward = 151.0
# training episode 31 of 1000 complete,  explore val = 0.01, episode reward = 105.0
# training episode 32 of 1000 complete,  explore val = 0.01, episode reward = 80.0
# training episode 33 of 1000 complete,  explore val = 0.01, episode reward = 425.0
# training episode 34 of 1000 complete,  explore val = 0.01, episode reward = 218.0
# training episode 35 of 1000 complete,  explore val = 0.01, episode reward = 223.0
# training episode 36 of 1000 complete,  explore val = 0.01, episode reward = 84.0
# training episode 37 of 1000 complete,  explore val = 0.01, episode reward = 281.0
# training episode 38 of 1000 complete,  explore val = 0.01, episode reward = 112.0
# training episode 39 of 1000 complete,  explore val = 0.01, episode reward = 289.0
# training episode 40 of 1000 complete,  explore val = 0.01, episode reward = 94.0
# training episode 41 of 1000 complete,  explore val = 0.01, episode reward = 193.0
# training episode 42 of 1000 complete,  explore val = 0.01, episode reward = 131.0
# training episode 43 of 1000 complete,  explore val = 0.01, episode reward = 196.0
# training episode 44 of 1000 complete,  explore val = 0.01, episode reward = 106.0
# training episode 45 of 1000 complete,  explore val = 0.01, episode reward = 139.0
# training episode 46 of 1000 complete,  explore val = 0.01, episode reward = 123.0
# training episode 47 of 1000 complete,  explore val = 0.01, episode reward = 176.0
# training episode 48 of 1000 complete,  explore val = 0.01, episode reward = 121.0
# training episode 49 of 1000 complete,  explore val = 0.01, episode reward = 136.0
# training episode 50 of 1000 complete,  explore val = 0.01, episode reward = 125.0
# training episode 51 of 1000 complete,  explore val = 0.01, episode reward = 144.0
# training episode 52 of 1000 complete,  explore val = 0.01, episode reward = 120.0
# training episode 53 of 1000 complete,  explore val = 0.01, episode reward = 165.0
# training episode 54 of 1000 complete,  explore val = 0.01, episode reward = 213.0
# training episode 55 of 1000 complete,  explore val = 0.01, episode reward = 291.0
# training episode 56 of 1000 complete,  explore val = 0.01, episode reward = 274.0
# training episode 57 of 1000 complete,  explore val = 0.01, episode reward = 380.0
# training episode 58 of 1000 complete,  explore val = 0.01, episode reward = 411.0
# training episode 59 of 1000 complete,  explore val = 0.01, episode reward = 272.0
# training episode 60 of 1000 complete,  explore val = 0.01, episode reward = 269.0
# training episode 61 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 62 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 63 of 1000 complete,  explore val = 0.01, episode reward = 311.0
# training episode 64 of 1000 complete,  explore val = 0.01, episode reward = 226.0
# training episode 65 of 1000 complete,  explore val = 0.01, episode reward = 328.0
# training episode 66 of 1000 complete,  explore val = 0.01, episode reward = 162.0
# training episode 67 of 1000 complete,  explore val = 0.01, episode reward = 216.0
# training episode 68 of 1000 complete,  explore val = 0.01, episode reward = 109.0
# training episode 69 of 1000 complete,  explore val = 0.01, episode reward = 134.0
# training episode 70 of 1000 complete,  explore val = 0.01, episode reward = 60.0
# training episode 71 of 1000 complete,  explore val = 0.01, episode reward = 57.0
# training episode 72 of 1000 complete,  explore val = 0.01, episode reward = 45.0
# training episode 73 of 1000 complete,  explore val = 0.01, episode reward = 38.0
# training episode 74 of 1000 complete,  explore val = 0.01, episode reward = 38.0
# training episode 75 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 76 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 77 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 78 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 79 of 1000 complete,  explore val = 0.01, episode reward = 54.0
# training episode 80 of 1000 complete,  explore val = 0.01, episode reward = 52.0
# training episode 81 of 1000 complete,  explore val = 0.01, episode reward = 71.0
# training episode 82 of 1000 complete,  explore val = 0.01, episode reward = 188.0
# training episode 83 of 1000 complete,  explore val = 0.01, episode reward = 210.0
# training episode 84 of 1000 complete,  explore val = 0.01, episode reward = 354.0
# training episode 85 of 1000 complete,  explore val = 0.01, episode reward = 395.0
# training episode 86 of 1000 complete,  explore val = 0.01, episode reward = 272.0
# training episode 87 of 1000 complete,  explore val = 0.01, episode reward = 471.0
# training episode 88 of 1000 complete,  explore val = 0.01, episode reward = 204.0
# training episode 89 of 1000 complete,  explore val = 0.01, episode reward = 450.0
# training episode 90 of 1000 complete,  explore val = 0.01, episode reward = 161.0
# training episode 91 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 92 of 1000 complete,  explore val = 0.01, episode reward = 114.0
# training episode 93 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 94 of 1000 complete,  explore val = 0.01, episode reward = 63.0
# training episode 95 of 1000 complete,  explore val = 0.01, episode reward = 103.0
# training episode 96 of 1000 complete,  explore val = 0.01, episode reward = 21.0
# training episode 97 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 98 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 99 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 100 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 101 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 102 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 103 of 1000 complete,  explore val = 0.01, episode reward = 139.0
# training episode 104 of 1000 complete,  explore val = 0.01, episode reward = 226.0
# training episode 105 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 106 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 107 of 1000 complete,  explore val = 0.01, episode reward = 316.0
# training episode 108 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 109 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 110 of 1000 complete,  explore val = 0.01, episode reward = 345.0
# training episode 111 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 112 of 1000 complete,  explore val = 0.01, episode reward = 389.0
# training episode 113 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 114 of 1000 complete,  explore val = 0.01, episode reward = 259.0
# training episode 115 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 116 of 1000 complete,  explore val = 0.01, episode reward = 225.0
# training episode 117 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 118 of 1000 complete,  explore val = 0.01, episode reward = 206.0
# training episode 119 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 120 of 1000 complete,  explore val = 0.01, episode reward = 221.0
# training episode 121 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 122 of 1000 complete,  explore val = 0.01, episode reward = 204.0
# training episode 123 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 124 of 1000 complete,  explore val = 0.01, episode reward = 203.0
# training episode 125 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 126 of 1000 complete,  explore val = 0.01, episode reward = 183.0
# training episode 127 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 128 of 1000 complete,  explore val = 0.01, episode reward = 168.0
# training episode 129 of 1000 complete,  explore val = 0.01, episode reward = 266.0
# training episode 130 of 1000 complete,  explore val = 0.01, episode reward = 161.0
# training episode 131 of 1000 complete,  explore val = 0.01, episode reward = 221.0
# training episode 132 of 1000 complete,  explore val = 0.01, episode reward = 167.0
# training episode 133 of 1000 complete,  explore val = 0.01, episode reward = 180.0
# training episode 134 of 1000 complete,  explore val = 0.01, episode reward = 214.0
# training episode 135 of 1000 complete,  explore val = 0.01, episode reward = 171.0
# training episode 136 of 1000 complete,  explore val = 0.01, episode reward = 165.0
# training episode 137 of 1000 complete,  explore val = 0.01, episode reward = 61.0
# training episode 138 of 1000 complete,  explore val = 0.01, episode reward = 163.0
# training episode 139 of 1000 complete,  explore val = 0.01, episode reward = 29.0
# training episode 140 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 141 of 1000 complete,  explore val = 0.01, episode reward = 65.0
# training episode 142 of 1000 complete,  explore val = 0.01, episode reward = 92.0
# training episode 143 of 1000 complete,  explore val = 0.01, episode reward = 42.0
# training episode 144 of 1000 complete,  explore val = 0.01, episode reward = 62.0
# training episode 145 of 1000 complete,  explore val = 0.01, episode reward = 48.0
# training episode 146 of 1000 complete,  explore val = 0.01, episode reward = 50.0
# training episode 147 of 1000 complete,  explore val = 0.01, episode reward = 54.0
# training episode 148 of 1000 complete,  explore val = 0.01, episode reward = 42.0
# training episode 149 of 1000 complete,  explore val = 0.01, episode reward = 62.0
# training episode 150 of 1000 complete,  explore val = 0.01, episode reward = 59.0
# training episode 151 of 1000 complete,  explore val = 0.01, episode reward = 42.0
# training episode 152 of 1000 complete,  explore val = 0.01, episode reward = 432.0
# training episode 153 of 1000 complete,  explore val = 0.01, episode reward = 21.0
# training episode 154 of 1000 complete,  explore val = 0.01, episode reward = 143.0
# training episode 155 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 156 of 1000 complete,  explore val = 0.01, episode reward = 126.0
# training episode 157 of 1000 complete,  explore val = 0.01, episode reward = 35.0
# training episode 158 of 1000 complete,  explore val = 0.01, episode reward = 116.0
# training episode 159 of 1000 complete,  explore val = 0.01, episode reward = 44.0
# training episode 160 of 1000 complete,  explore val = 0.01, episode reward = 70.0
# training episode 161 of 1000 complete,  explore val = 0.01, episode reward = 42.0
# training episode 162 of 1000 complete,  explore val = 0.01, episode reward = 101.0
# training episode 163 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 164 of 1000 complete,  explore val = 0.01, episode reward = 96.0
# training episode 165 of 1000 complete,  explore val = 0.01, episode reward = 173.0
# training episode 166 of 1000 complete,  explore val = 0.01, episode reward = 95.0
# training episode 167 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 168 of 1000 complete,  explore val = 0.01, episode reward = 79.0
# training episode 169 of 1000 complete,  explore val = 0.01, episode reward = 321.0
# training episode 170 of 1000 complete,  explore val = 0.01, episode reward = 92.0
# training episode 171 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 172 of 1000 complete,  explore val = 0.01, episode reward = 86.0
# training episode 173 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 174 of 1000 complete,  explore val = 0.01, episode reward = 51.0
# training episode 175 of 1000 complete,  explore val = 0.01, episode reward = 175.0
# training episode 176 of 1000 complete,  explore val = 0.01, episode reward = 66.0
# training episode 177 of 1000 complete,  explore val = 0.01, episode reward = 159.0
# training episode 178 of 1000 complete,  explore val = 0.01, episode reward = 64.0
# training episode 179 of 1000 complete,  explore val = 0.01, episode reward = 171.0
# training episode 180 of 1000 complete,  explore val = 0.01, episode reward = 42.0
# training episode 181 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 182 of 1000 complete,  explore val = 0.01, episode reward = 24.0
# training episode 183 of 1000 complete,  explore val = 0.01, episode reward = 157.0
# training episode 184 of 1000 complete,  explore val = 0.01, episode reward = 40.0
# training episode 185 of 1000 complete,  explore val = 0.01, episode reward = 184.0
# training episode 186 of 1000 complete,  explore val = 0.01, episode reward = 30.0
# training episode 187 of 1000 complete,  explore val = 0.01, episode reward = 217.0
# training episode 188 of 1000 complete,  explore val = 0.01, episode reward = 102.0
# training episode 189 of 1000 complete,  explore val = 0.01, episode reward = 207.0
# training episode 190 of 1000 complete,  explore val = 0.01, episode reward = 28.0
# training episode 191 of 1000 complete,  explore val = 0.01, episode reward = 192.0
# training episode 192 of 1000 complete,  explore val = 0.01, episode reward = 148.0
# training episode 193 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 194 of 1000 complete,  explore val = 0.01, episode reward = 38.0
# training episode 195 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 196 of 1000 complete,  explore val = 0.01, episode reward = 108.0
# training episode 197 of 1000 complete,  explore val = 0.01, episode reward = 454.0
# training episode 198 of 1000 complete,  explore val = 0.01, episode reward = 123.0
# training episode 199 of 1000 complete,  explore val = 0.01, episode reward = 332.0
# training episode 200 of 1000 complete,  explore val = 0.01, episode reward = 130.0
# training episode 201 of 1000 complete,  explore val = 0.01, episode reward = 324.0
# training episode 202 of 1000 complete,  explore val = 0.01, episode reward = 117.0
# training episode 203 of 1000 complete,  explore val = 0.01, episode reward = 269.0
# training episode 204 of 1000 complete,  explore val = 0.01, episode reward = 109.0
# training episode 205 of 1000 complete,  explore val = 0.01, episode reward = 293.0
# training episode 206 of 1000 complete,  explore val = 0.01, episode reward = 19.0
# training episode 207 of 1000 complete,  explore val = 0.01, episode reward = 328.0
# training episode 208 of 1000 complete,  explore val = 0.01, episode reward = 125.0
# training episode 209 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 210 of 1000 complete,  explore val = 0.01, episode reward = 104.0
# training episode 211 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 212 of 1000 complete,  explore val = 0.01, episode reward = 126.0
# training episode 213 of 1000 complete,  explore val = 0.01, episode reward = 422.0
# training episode 214 of 1000 complete,  explore val = 0.01, episode reward = 243.0
# training episode 215 of 1000 complete,  explore val = 0.01, episode reward = 186.0
# training episode 216 of 1000 complete,  explore val = 0.01, episode reward = 254.0
# training episode 217 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 218 of 1000 complete,  explore val = 0.01, episode reward = 273.0
# training episode 219 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 220 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 221 of 1000 complete,  explore val = 0.01, episode reward = 139.0
# training episode 222 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 223 of 1000 complete,  explore val = 0.01, episode reward = 16.0
# training episode 224 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 225 of 1000 complete,  explore val = 0.01, episode reward = 119.0
# training episode 226 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 227 of 1000 complete,  explore val = 0.01, episode reward = 110.0
# training episode 228 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 229 of 1000 complete,  explore val = 0.01, episode reward = 63.0
# training episode 230 of 1000 complete,  explore val = 0.01, episode reward = 338.0
# training episode 231 of 1000 complete,  explore val = 0.01, episode reward = 19.0
# training episode 232 of 1000 complete,  explore val = 0.01, episode reward = 227.0
# training episode 233 of 1000 complete,  explore val = 0.01, episode reward = 36.0
# training episode 234 of 1000 complete,  explore val = 0.01, episode reward = 174.0
# training episode 235 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 236 of 1000 complete,  explore val = 0.01, episode reward = 231.0
# training episode 237 of 1000 complete,  explore val = 0.01, episode reward = 27.0
# training episode 238 of 1000 complete,  explore val = 0.01, episode reward = 160.0
# training episode 239 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 240 of 1000 complete,  explore val = 0.01, episode reward = 128.0
# training episode 241 of 1000 complete,  explore val = 0.01, episode reward = 22.0
# training episode 242 of 1000 complete,  explore val = 0.01, episode reward = 144.0
# training episode 243 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 244 of 1000 complete,  explore val = 0.01, episode reward = 117.0
# training episode 245 of 1000 complete,  explore val = 0.01, episode reward = 470.0
# training episode 246 of 1000 complete,  explore val = 0.01, episode reward = 20.0
# training episode 247 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 248 of 1000 complete,  explore val = 0.01, episode reward = 22.0
# training episode 249 of 1000 complete,  explore val = 0.01, episode reward = 326.0
# training episode 250 of 1000 complete,  explore val = 0.01, episode reward = 127.0
# training episode 251 of 1000 complete,  explore val = 0.01, episode reward = 310.0
# training episode 252 of 1000 complete,  explore val = 0.01, episode reward = 142.0
# training episode 253 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 254 of 1000 complete,  explore val = 0.01, episode reward = 26.0
# training episode 255 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 256 of 1000 complete,  explore val = 0.01, episode reward = 97.0
# training episode 257 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 258 of 1000 complete,  explore val = 0.01, episode reward = 165.0
# training episode 259 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 260 of 1000 complete,  explore val = 0.01, episode reward = 156.0
# training episode 261 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 262 of 1000 complete,  explore val = 0.01, episode reward = 220.0
# training episode 263 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 264 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 265 of 1000 complete,  explore val = 0.01, episode reward = 150.0
# training episode 266 of 1000 complete,  explore val = 0.01, episode reward = 175.0
# training episode 267 of 1000 complete,  explore val = 0.01, episode reward = 97.0
# training episode 268 of 1000 complete,  explore val = 0.01, episode reward = 243.0
# training episode 269 of 1000 complete,  explore val = 0.01, episode reward = 97.0
# training episode 270 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 271 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 272 of 1000 complete,  explore val = 0.01, episode reward = 235.0
# training episode 273 of 1000 complete,  explore val = 0.01, episode reward = 106.0
# training episode 274 of 1000 complete,  explore val = 0.01, episode reward = 225.0
# training episode 275 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 276 of 1000 complete,  explore val = 0.01, episode reward = 180.0
# training episode 277 of 1000 complete,  explore val = 0.01, episode reward = 118.0
# training episode 278 of 1000 complete,  explore val = 0.01, episode reward = 386.0
# training episode 279 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 280 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 281 of 1000 complete,  explore val = 0.01, episode reward = 19.0
# training episode 282 of 1000 complete,  explore val = 0.01, episode reward = 19.0
# training episode 283 of 1000 complete,  explore val = 0.01, episode reward = 421.0
# training episode 284 of 1000 complete,  explore val = 0.01, episode reward = 19.0
# training episode 285 of 1000 complete,  explore val = 0.01, episode reward = 266.0
# training episode 286 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 287 of 1000 complete,  explore val = 0.01, episode reward = 14.0
# training episode 288 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 289 of 1000 complete,  explore val = 0.01, episode reward = 20.0
# training episode 290 of 1000 complete,  explore val = 0.01, episode reward = 202.0
# training episode 291 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 292 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 293 of 1000 complete,  explore val = 0.01, episode reward = 356.0
# training episode 294 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 295 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 296 of 1000 complete,  explore val = 0.01, episode reward = 9.0
# training episode 297 of 1000 complete,  explore val = 0.01, episode reward = 9.0
# training episode 298 of 1000 complete,  explore val = 0.01, episode reward = 182.0
# training episode 299 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 300 of 1000 complete,  explore val = 0.01, episode reward = 100.0
# training episode 301 of 1000 complete,  explore val = 0.01, episode reward = 153.0
# training episode 302 of 1000 complete,  explore val = 0.01, episode reward = 9.0
# training episode 303 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 304 of 1000 complete,  explore val = 0.01, episode reward = 9.0
# training episode 305 of 1000 complete,  explore val = 0.01, episode reward = 9.0
# training episode 306 of 1000 complete,  explore val = 0.01, episode reward = 11.0
# training episode 307 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 308 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 309 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 310 of 1000 complete,  explore val = 0.01, episode reward = 335.0
# training episode 311 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 312 of 1000 complete,  explore val = 0.01, episode reward = 289.0
# training episode 313 of 1000 complete,  explore val = 0.01, episode reward = 255.0
# training episode 314 of 1000 complete,  explore val = 0.01, episode reward = 205.0
# training episode 315 of 1000 complete,  explore val = 0.01, episode reward = 20.0
# training episode 316 of 1000 complete,  explore val = 0.01, episode reward = 179.0
# training episode 317 of 1000 complete,  explore val = 0.01, episode reward = 191.0
# training episode 318 of 1000 complete,  explore val = 0.01, episode reward = 23.0
# training episode 319 of 1000 complete,  explore val = 0.01, episode reward = 21.0
# training episode 320 of 1000 complete,  explore val = 0.01, episode reward = 213.0
# training episode 321 of 1000 complete,  explore val = 0.01, episode reward = 20.0
# training episode 322 of 1000 complete,  explore val = 0.01, episode reward = 206.0
# training episode 323 of 1000 complete,  explore val = 0.01, episode reward = 173.0
# training episode 324 of 1000 complete,  explore val = 0.01, episode reward = 252.0
# training episode 325 of 1000 complete,  explore val = 0.01, episode reward = 152.0
# training episode 326 of 1000 complete,  explore val = 0.01, episode reward = 449.0
# training episode 327 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 328 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 329 of 1000 complete,  explore val = 0.01, episode reward = 164.0
# training episode 330 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 331 of 1000 complete,  explore val = 0.01, episode reward = 14.0
# training episode 332 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 333 of 1000 complete,  explore val = 0.01, episode reward = 431.0
# training episode 334 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 335 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 336 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 337 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 338 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 339 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 340 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 341 of 1000 complete,  explore val = 0.01, episode reward = 114.0
# training episode 342 of 1000 complete,  explore val = 0.01, episode reward = 249.0
# training episode 343 of 1000 complete,  explore val = 0.01, episode reward = 178.0
# training episode 344 of 1000 complete,  explore val = 0.01, episode reward = 283.0
# training episode 345 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 346 of 1000 complete,  explore val = 0.01, episode reward = 242.0
# training episode 347 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 348 of 1000 complete,  explore val = 0.01, episode reward = 198.0
# training episode 349 of 1000 complete,  explore val = 0.01, episode reward = 496.0
# training episode 350 of 1000 complete,  explore val = 0.01, episode reward = 210.0
# training episode 351 of 1000 complete,  explore val = 0.01, episode reward = 203.0
# training episode 352 of 1000 complete,  explore val = 0.01, episode reward = 163.0
# training episode 353 of 1000 complete,  explore val = 0.01, episode reward = 149.0
# training episode 354 of 1000 complete,  explore val = 0.01, episode reward = 115.0
# training episode 355 of 1000 complete,  explore val = 0.01, episode reward = 112.0
# training episode 356 of 1000 complete,  explore val = 0.01, episode reward = 102.0
# training episode 357 of 1000 complete,  explore val = 0.01, episode reward = 128.0
# training episode 358 of 1000 complete,  explore val = 0.01, episode reward = 91.0
# training episode 359 of 1000 complete,  explore val = 0.01, episode reward = 101.0
# training episode 360 of 1000 complete,  explore val = 0.01, episode reward = 341.0
# training episode 361 of 1000 complete,  explore val = 0.01, episode reward = 39.0
# training episode 362 of 1000 complete,  explore val = 0.01, episode reward = 332.0
# training episode 363 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 364 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 365 of 1000 complete,  explore val = 0.01, episode reward = 8.0
# training episode 366 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 367 of 1000 complete,  explore val = 0.01, episode reward = 20.0
# training episode 368 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 369 of 1000 complete,  explore val = 0.01, episode reward = 156.0
# training episode 370 of 1000 complete,  explore val = 0.01, episode reward = 364.0
# training episode 371 of 1000 complete,  explore val = 0.01, episode reward = 123.0
# training episode 372 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 373 of 1000 complete,  explore val = 0.01, episode reward = 182.0
# training episode 374 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 375 of 1000 complete,  explore val = 0.01, episode reward = 273.0
# training episode 376 of 1000 complete,  explore val = 0.01, episode reward = 391.0
# training episode 377 of 1000 complete,  explore val = 0.01, episode reward = 228.0
# training episode 378 of 1000 complete,  explore val = 0.01, episode reward = 254.0
# training episode 379 of 1000 complete,  explore val = 0.01, episode reward = 161.0
# training episode 380 of 1000 complete,  explore val = 0.01, episode reward = 133.0
# training episode 381 of 1000 complete,  explore val = 0.01, episode reward = 94.0
# training episode 382 of 1000 complete,  explore val = 0.01, episode reward = 121.0
# training episode 383 of 1000 complete,  explore val = 0.01, episode reward = 137.0
# training episode 384 of 1000 complete,  explore val = 0.01, episode reward = 91.0
# training episode 385 of 1000 complete,  explore val = 0.01, episode reward = 205.0
# training episode 386 of 1000 complete,  explore val = 0.01, episode reward = 71.0
# training episode 387 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 388 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 389 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 390 of 1000 complete,  explore val = 0.01, episode reward = 206.0
# training episode 391 of 1000 complete,  explore val = 0.01, episode reward = 308.0
# training episode 392 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 393 of 1000 complete,  explore val = 0.01, episode reward = 176.0
# training episode 394 of 1000 complete,  explore val = 0.01, episode reward = 8.0
# training episode 395 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 396 of 1000 complete,  explore val = 0.01, episode reward = 39.0
# training episode 397 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 398 of 1000 complete,  explore val = 0.01, episode reward = 247.0
# training episode 399 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 400 of 1000 complete,  explore val = 0.01, episode reward = 221.0
# training episode 401 of 1000 complete,  explore val = 0.01, episode reward = 213.0
# training episode 402 of 1000 complete,  explore val = 0.01, episode reward = 155.0
# training episode 403 of 1000 complete,  explore val = 0.01, episode reward = 150.0
# training episode 404 of 1000 complete,  explore val = 0.01, episode reward = 344.0
# training episode 405 of 1000 complete,  explore val = 0.01, episode reward = 366.0
# training episode 406 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 407 of 1000 complete,  explore val = 0.01, episode reward = 466.0
# training episode 408 of 1000 complete,  explore val = 0.01, episode reward = 380.0
# training episode 409 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 410 of 1000 complete,  explore val = 0.01, episode reward = 276.0
# training episode 411 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 412 of 1000 complete,  explore val = 0.01, episode reward = 306.0
# training episode 413 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 414 of 1000 complete,  explore val = 0.01, episode reward = 113.0
# training episode 415 of 1000 complete,  explore val = 0.01, episode reward = 344.0
# training episode 416 of 1000 complete,  explore val = 0.01, episode reward = 49.0
# training episode 417 of 1000 complete,  explore val = 0.01, episode reward = 69.0
# training episode 418 of 1000 complete,  explore val = 0.01, episode reward = 16.0
# training episode 419 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 420 of 1000 complete,  explore val = 0.01, episode reward = 51.0
# training episode 421 of 1000 complete,  explore val = 0.01, episode reward = 60.0
# training episode 422 of 1000 complete,  explore val = 0.01, episode reward = 57.0
# training episode 423 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 424 of 1000 complete,  explore val = 0.01, episode reward = 98.0
# training episode 425 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 426 of 1000 complete,  explore val = 0.01, episode reward = 22.0
# training episode 427 of 1000 complete,  explore val = 0.01, episode reward = 10.0
# training episode 428 of 1000 complete,  explore val = 0.01, episode reward = 24.0
# training episode 429 of 1000 complete,  explore val = 0.01, episode reward = 43.0
# training episode 430 of 1000 complete,  explore val = 0.01, episode reward = 23.0
# training episode 431 of 1000 complete,  explore val = 0.01, episode reward = 23.0
# training episode 432 of 1000 complete,  explore val = 0.01, episode reward = 26.0
# training episode 433 of 1000 complete,  explore val = 0.01, episode reward = 47.0
# training episode 434 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 435 of 1000 complete,  explore val = 0.01, episode reward = 29.0
# training episode 436 of 1000 complete,  explore val = 0.01, episode reward = 209.0
# training episode 437 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 438 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 439 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 440 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 441 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 442 of 1000 complete,  explore val = 0.01, episode reward = 322.0
# training episode 443 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 444 of 1000 complete,  explore val = 0.01, episode reward = 36.0
# training episode 445 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 446 of 1000 complete,  explore val = 0.01, episode reward = 40.0
# training episode 447 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 448 of 1000 complete,  explore val = 0.01, episode reward = 192.0
# training episode 449 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 450 of 1000 complete,  explore val = 0.01, episode reward = 290.0
# training episode 451 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 452 of 1000 complete,  explore val = 0.01, episode reward = 311.0
# training episode 453 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 454 of 1000 complete,  explore val = 0.01, episode reward = 366.0
# training episode 455 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 456 of 1000 complete,  explore val = 0.01, episode reward = 89.0
# training episode 457 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 458 of 1000 complete,  explore val = 0.01, episode reward = 22.0
# training episode 459 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 460 of 1000 complete,  explore val = 0.01, episode reward = 212.0
# training episode 461 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 462 of 1000 complete,  explore val = 0.01, episode reward = 202.0
# training episode 463 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 464 of 1000 complete,  explore val = 0.01, episode reward = 246.0
# training episode 465 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 466 of 1000 complete,  explore val = 0.01, episode reward = 28.0
# training episode 467 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 468 of 1000 complete,  explore val = 0.01, episode reward = 83.0
# training episode 469 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 470 of 1000 complete,  explore val = 0.01, episode reward = 19.0
# training episode 471 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 472 of 1000 complete,  explore val = 0.01, episode reward = 82.0
# training episode 473 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 474 of 1000 complete,  explore val = 0.01, episode reward = 27.0
# training episode 475 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 476 of 1000 complete,  explore val = 0.01, episode reward = 75.0
# training episode 477 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 478 of 1000 complete,  explore val = 0.01, episode reward = 25.0
# training episode 479 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 480 of 1000 complete,  explore val = 0.01, episode reward = 25.0
# training episode 481 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 482 of 1000 complete,  explore val = 0.01, episode reward = 30.0
# training episode 483 of 1000 complete,  explore val = 0.01, episode reward = 412.0
# training episode 484 of 1000 complete,  explore val = 0.01, episode reward = 69.0
# training episode 485 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 486 of 1000 complete,  explore val = 0.01, episode reward = 22.0
# training episode 487 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 488 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 489 of 1000 complete,  explore val = 0.01, episode reward = 394.0
# training episode 490 of 1000 complete,  explore val = 0.01, episode reward = 25.0
# training episode 491 of 1000 complete,  explore val = 0.01, episode reward = 464.0
# training episode 492 of 1000 complete,  explore val = 0.01, episode reward = 29.0
# training episode 493 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 494 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 495 of 1000 complete,  explore val = 0.01, episode reward = 334.0
# training episode 496 of 1000 complete,  explore val = 0.01, episode reward = 177.0
# training episode 497 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 498 of 1000 complete,  explore val = 0.01, episode reward = 119.0
# training episode 499 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 500 of 1000 complete,  explore val = 0.01, episode reward = 27.0
# training episode 501 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 502 of 1000 complete,  explore val = 0.01, episode reward = 228.0
# training episode 503 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 504 of 1000 complete,  explore val = 0.01, episode reward = 458.0
# training episode 505 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 506 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 507 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 508 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 509 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 510 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 511 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 512 of 1000 complete,  explore val = 0.01, episode reward = 262.0
# training episode 513 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 514 of 1000 complete,  explore val = 0.01, episode reward = 302.0
# training episode 515 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 516 of 1000 complete,  explore val = 0.01, episode reward = 411.0
# training episode 517 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 518 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 519 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 520 of 1000 complete,  explore val = 0.01, episode reward = 496.0
# training episode 521 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 522 of 1000 complete,  explore val = 0.01, episode reward = 425.0
# training episode 523 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 524 of 1000 complete,  explore val = 0.01, episode reward = 315.0
# training episode 525 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 526 of 1000 complete,  explore val = 0.01, episode reward = 85.0
# training episode 527 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 528 of 1000 complete,  explore val = 0.01, episode reward = 261.0
# training episode 529 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 530 of 1000 complete,  explore val = 0.01, episode reward = 81.0
# training episode 531 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 532 of 1000 complete,  explore val = 0.01, episode reward = 75.0
# training episode 533 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 534 of 1000 complete,  explore val = 0.01, episode reward = 24.0
# training episode 535 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 536 of 1000 complete,  explore val = 0.01, episode reward = 25.0
# training episode 537 of 1000 complete,  explore val = 0.01, episode reward = 388.0
# training episode 538 of 1000 complete,  explore val = 0.01, episode reward = 20.0
# training episode 539 of 1000 complete,  explore val = 0.01, episode reward = 20.0
# training episode 540 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 541 of 1000 complete,  explore val = 0.01, episode reward = 17.0
# training episode 542 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 543 of 1000 complete,  explore val = 0.01, episode reward = 20.0
# training episode 544 of 1000 complete,  explore val = 0.01, episode reward = 154.0
# training episode 545 of 1000 complete,  explore val = 0.01, episode reward = 442.0
# training episode 546 of 1000 complete,  explore val = 0.01, episode reward = 22.0
# training episode 547 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 548 of 1000 complete,  explore val = 0.01, episode reward = 162.0
# training episode 549 of 1000 complete,  explore val = 0.01, episode reward = 445.0
# training episode 550 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 551 of 1000 complete,  explore val = 0.01, episode reward = 327.0
# training episode 552 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 553 of 1000 complete,  explore val = 0.01, episode reward = 327.0
# training episode 554 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 555 of 1000 complete,  explore val = 0.01, episode reward = 307.0
# training episode 556 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 557 of 1000 complete,  explore val = 0.01, episode reward = 305.0
# training episode 558 of 1000 complete,  explore val = 0.01, episode reward = 339.0
# training episode 559 of 1000 complete,  explore val = 0.01, episode reward = 295.0
# training episode 560 of 1000 complete,  explore val = 0.01, episode reward = 162.0
# training episode 561 of 1000 complete,  explore val = 0.01, episode reward = 254.0
# training episode 562 of 1000 complete,  explore val = 0.01, episode reward = 115.0
# training episode 563 of 1000 complete,  explore val = 0.01, episode reward = 250.0
# training episode 564 of 1000 complete,  explore val = 0.01, episode reward = 148.0
# training episode 565 of 1000 complete,  explore val = 0.01, episode reward = 261.0
# training episode 566 of 1000 complete,  explore val = 0.01, episode reward = 119.0
# training episode 567 of 1000 complete,  explore val = 0.01, episode reward = 345.0
# training episode 568 of 1000 complete,  explore val = 0.01, episode reward = 57.0
# training episode 569 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 570 of 1000 complete,  explore val = 0.01, episode reward = 38.0
# training episode 571 of 1000 complete,  explore val = 0.01, episode reward = 235.0
# training episode 572 of 1000 complete,  explore val = 0.01, episode reward = 39.0
# training episode 573 of 1000 complete,  explore val = 0.01, episode reward = 108.0
# training episode 574 of 1000 complete,  explore val = 0.01, episode reward = 30.0
# training episode 575 of 1000 complete,  explore val = 0.01, episode reward = 28.0
# training episode 576 of 1000 complete,  explore val = 0.01, episode reward = 18.0
# training episode 577 of 1000 complete,  explore val = 0.01, episode reward = 34.0
# training episode 578 of 1000 complete,  explore val = 0.01, episode reward = 23.0
# training episode 579 of 1000 complete,  explore val = 0.01, episode reward = 73.0
# training episode 580 of 1000 complete,  explore val = 0.01, episode reward = 114.0
# training episode 581 of 1000 complete,  explore val = 0.01, episode reward = 326.0
# training episode 582 of 1000 complete,  explore val = 0.01, episode reward = 395.0
# ...
# training episode 809 of 1000 complete,  explore val = 0.01, episode reward = 234.0
# training episode 810 of 1000 complete,  explore val = 0.01, episode reward = 110.0
# training episode 811 of 1000 complete,  explore val = 0.01, episode reward = 257.0
# training episode 812 of 1000 complete,  explore val = 0.01, episode reward = 133.0
# training episode 813 of 1000 complete,  explore val = 0.01, episode reward = 255.0
# training episode 814 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 815 of 1000 complete,  explore val = 0.01, episode reward = 225.0
# training episode 816 of 1000 complete,  explore val = 0.01, episode reward = 406.0
# training episode 817 of 1000 complete,  explore val = 0.01, episode reward = 225.0
# training episode 818 of 1000 complete,  explore val = 0.01, episode reward = 336.0
# training episode 819 of 1000 complete,  explore val = 0.01, episode reward = 201.0
# training episode 820 of 1000 complete,  explore val = 0.01, episode reward = 261.0
# training episode 821 of 1000 complete,  explore val = 0.01, episode reward = 198.0
# training episode 822 of 1000 complete,  explore val = 0.01, episode reward = 317.0
# training episode 823 of 1000 complete,  explore val = 0.01, episode reward = 196.0
# training episode 824 of 1000 complete,  explore val = 0.01, episode reward = 316.0
# training episode 825 of 1000 complete,  explore val = 0.01, episode reward = 170.0
# training episode 826 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 827 of 1000 complete,  explore val = 0.01, episode reward = 150.0
# training episode 828 of 1000 complete,  explore val = 0.01, episode reward = 342.0
# training episode 829 of 1000 complete,  explore val = 0.01, episode reward = 153.0
# training episode 830 of 1000 complete,  explore val = 0.01, episode reward = 386.0
# training episode 831 of 1000 complete,  explore val = 0.01, episode reward = 185.0
# training episode 832 of 1000 complete,  explore val = 0.01, episode reward = 243.0
# training episode 833 of 1000 complete,  explore val = 0.01, episode reward = 190.0
# training episode 834 of 1000 complete,  explore val = 0.01, episode reward = 239.0
# training episode 835 of 1000 complete,  explore val = 0.01, episode reward = 200.0
# training episode 836 of 1000 complete,  explore val = 0.01, episode reward = 190.0
# training episode 837 of 1000 complete,  explore val = 0.01, episode reward = 187.0
# training episode 838 of 1000 complete,  explore val = 0.01, episode reward = 136.0
# training episode 839 of 1000 complete,  explore val = 0.01, episode reward = 201.0
# training episode 840 of 1000 complete,  explore val = 0.01, episode reward = 147.0
# training episode 841 of 1000 complete,  explore val = 0.01, episode reward = 244.0
# training episode 842 of 1000 complete,  explore val = 0.01, episode reward = 133.0
# training episode 843 of 1000 complete,  explore val = 0.01, episode reward = 292.0
# training episode 844 of 1000 complete,  explore val = 0.01, episode reward = 153.0
# training episode 845 of 1000 complete,  explore val = 0.01, episode reward = 297.0
# training episode 846 of 1000 complete,  explore val = 0.01, episode reward = 358.0
# training episode 847 of 1000 complete,  explore val = 0.01, episode reward = 263.0
# training episode 848 of 1000 complete,  explore val = 0.01, episode reward = 499.0
# training episode 849 of 1000 complete,  explore val = 0.01, episode reward = 215.0
# training episode 850 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 851 of 1000 complete,  explore val = 0.01, episode reward = 232.0
# training episode 852 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 853 of 1000 complete,  explore val = 0.01, episode reward = 222.0
# training episode 854 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 855 of 1000 complete,  explore val = 0.01, episode reward = 172.0
# training episode 856 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 857 of 1000 complete,  explore val = 0.01, episode reward = 187.0
# training episode 858 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 859 of 1000 complete,  explore val = 0.01, episode reward = 191.0
# training episode 860 of 1000 complete,  explore val = 0.01, episode reward = 342.0
# training episode 861 of 1000 complete,  explore val = 0.01, episode reward = 175.0
# training episode 862 of 1000 complete,  explore val = 0.01, episode reward = 175.0
# training episode 863 of 1000 complete,  explore val = 0.01, episode reward = 165.0
# training episode 864 of 1000 complete,  explore val = 0.01, episode reward = 133.0
# training episode 865 of 1000 complete,  explore val = 0.01, episode reward = 193.0
# training episode 866 of 1000 complete,  explore val = 0.01, episode reward = 132.0
# training episode 867 of 1000 complete,  explore val = 0.01, episode reward = 204.0
# training episode 868 of 1000 complete,  explore val = 0.01, episode reward = 98.0
# training episode 869 of 1000 complete,  explore val = 0.01, episode reward = 208.0
# training episode 870 of 1000 complete,  explore val = 0.01, episode reward = 102.0
# training episode 871 of 1000 complete,  explore val = 0.01, episode reward = 316.0
# training episode 872 of 1000 complete,  explore val = 0.01, episode reward = 134.0
# training episode 873 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 874 of 1000 complete,  explore val = 0.01, episode reward = 161.0
# training episode 875 of 1000 complete,  explore val = 0.01, episode reward = 347.0
# training episode 876 of 1000 complete,  explore val = 0.01, episode reward = 228.0
# training episode 877 of 1000 complete,  explore val = 0.01, episode reward = 300.0
# training episode 878 of 1000 complete,  explore val = 0.01, episode reward = 233.0
# training episode 879 of 1000 complete,  explore val = 0.01, episode reward = 268.0
# training episode 880 of 1000 complete,  explore val = 0.01, episode reward = 225.0
# training episode 881 of 1000 complete,  explore val = 0.01, episode reward = 186.0
# training episode 882 of 1000 complete,  explore val = 0.01, episode reward = 191.0
# training episode 883 of 1000 complete,  explore val = 0.01, episode reward = 192.0
# training episode 884 of 1000 complete,  explore val = 0.01, episode reward = 226.0
# training episode 885 of 1000 complete,  explore val = 0.01, episode reward = 191.0
# training episode 886 of 1000 complete,  explore val = 0.01, episode reward = 249.0
# training episode 887 of 1000 complete,  explore val = 0.01, episode reward = 207.0
# training episode 888 of 1000 complete,  explore val = 0.01, episode reward = 223.0
# training episode 889 of 1000 complete,  explore val = 0.01, episode reward = 165.0
# training episode 890 of 1000 complete,  explore val = 0.01, episode reward = 183.0
# training episode 891 of 1000 complete,  explore val = 0.01, episode reward = 171.0
# training episode 892 of 1000 complete,  explore val = 0.01, episode reward = 229.0
# training episode 893 of 1000 complete,  explore val = 0.01, episode reward = 194.0
# training episode 894 of 1000 complete,  explore val = 0.01, episode reward = 273.0
# training episode 895 of 1000 complete,  explore val = 0.01, episode reward = 200.0
# training episode 896 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 897 of 1000 complete,  explore val = 0.01, episode reward = 223.0
# training episode 898 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 899 of 1000 complete,  explore val = 0.01, episode reward = 227.0
# training episode 900 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 901 of 1000 complete,  explore val = 0.01, episode reward = 229.0
# training episode 902 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 903 of 1000 complete,  explore val = 0.01, episode reward = 170.0
# training episode 904 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 905 of 1000 complete,  explore val = 0.01, episode reward = 136.0
# training episode 906 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 907 of 1000 complete,  explore val = 0.01, episode reward = 133.0
# training episode 908 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 909 of 1000 complete,  explore val = 0.01, episode reward = 149.0
# training episode 910 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 911 of 1000 complete,  explore val = 0.01, episode reward = 15.0
# training episode 912 of 1000 complete,  explore val = 0.01, episode reward = 285.0
# training episode 913 of 1000 complete,  explore val = 0.01, episode reward = 13.0
# training episode 914 of 1000 complete,  explore val = 0.01, episode reward = 191.0
# training episode 915 of 1000 complete,  explore val = 0.01, episode reward = 12.0
# training episode 916 of 1000 complete,  explore val = 0.01, episode reward = 131.0
# training episode 917 of 1000 complete,  explore val = 0.01, episode reward = 155.0
# training episode 918 of 1000 complete,  explore val = 0.01, episode reward = 85.0
# training episode 919 of 1000 complete,  explore val = 0.01, episode reward = 231.0
# training episode 920 of 1000 complete,  explore val = 0.01, episode reward = 71.0
# training episode 921 of 1000 complete,  explore val = 0.01, episode reward = 292.0
# training episode 922 of 1000 complete,  explore val = 0.01, episode reward = 60.0
# training episode 923 of 1000 complete,  explore val = 0.01, episode reward = 180.0
# training episode 924 of 1000 complete,  explore val = 0.01, episode reward = 64.0
# training episode 925 of 1000 complete,  explore val = 0.01, episode reward = 136.0
# training episode 926 of 1000 complete,  explore val = 0.01, episode reward = 85.0
# training episode 927 of 1000 complete,  explore val = 0.01, episode reward = 163.0
# training episode 928 of 1000 complete,  explore val = 0.01, episode reward = 92.0
# training episode 929 of 1000 complete,  explore val = 0.01, episode reward = 428.0
# training episode 930 of 1000 complete,  explore val = 0.01, episode reward = 16.0
# training episode 931 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 932 of 1000 complete,  explore val = 0.01, episode reward = 141.0
# training episode 933 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 934 of 1000 complete,  explore val = 0.01, episode reward = 298.0
# training episode 935 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 936 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 937 of 1000 complete,  explore val = 0.01, episode reward = 495.0
# training episode 938 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 939 of 1000 complete,  explore val = 0.01, episode reward = 410.0
# training episode 940 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 941 of 1000 complete,  explore val = 0.01, episode reward = 475.0
# training episode 942 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 943 of 1000 complete,  explore val = 0.01, episode reward = 348.0
# training episode 944 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 945 of 1000 complete,  explore val = 0.01, episode reward = 326.0
# training episode 946 of 1000 complete,  explore val = 0.01, episode reward = 448.0
# training episode 947 of 1000 complete,  explore val = 0.01, episode reward = 262.0
# training episode 948 of 1000 complete,  explore val = 0.01, episode reward = 257.0
# training episode 949 of 1000 complete,  explore val = 0.01, episode reward = 252.0
# training episode 950 of 1000 complete,  explore val = 0.01, episode reward = 240.0
# training episode 951 of 1000 complete,  explore val = 0.01, episode reward = 248.0
# training episode 952 of 1000 complete,  explore val = 0.01, episode reward = 212.0
# training episode 953 of 1000 complete,  explore val = 0.01, episode reward = 286.0
# training episode 954 of 1000 complete,  explore val = 0.01, episode reward = 170.0
# training episode 955 of 1000 complete,  explore val = 0.01, episode reward = 258.0
# training episode 956 of 1000 complete,  explore val = 0.01, episode reward = 147.0
# training episode 957 of 1000 complete,  explore val = 0.01, episode reward = 300.0
# training episode 958 of 1000 complete,  explore val = 0.01, episode reward = 153.0
# training episode 959 of 1000 complete,  explore val = 0.01, episode reward = 390.0
# training episode 960 of 1000 complete,  explore val = 0.01, episode reward = 192.0
# training episode 961 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 962 of 1000 complete,  explore val = 0.01, episode reward = 224.0
# training episode 963 of 1000 complete,  explore val = 0.01, episode reward = 500.0
# training episode 964 of 1000 complete,  explore val = 0.01, episode reward = 268.0
# training episode 965 of 1000 complete,  explore val = 0.01, episode reward = 385.0
# training episode 966 of 1000 complete,  explore val = 0.01, episode reward = 233.0
# training episode 967 of 1000 complete,  explore val = 0.01, episode reward = 334.0
# training episode 968 of 1000 complete,  explore val = 0.01, episode reward = 191.0
# training episode 969 of 1000 complete,  explore val = 0.01, episode reward = 226.0
# training episode 970 of 1000 complete,  explore val = 0.01, episode reward = 194.0
# training episode 971 of 1000 complete,  explore val = 0.01, episode reward = 225.0
# training episode 972 of 1000 complete,  explore val = 0.01, episode reward = 190.0
# training episode 973 of 1000 complete,  explore val = 0.01, episode reward = 248.0
# training episode 974 of 1000 complete,  explore val = 0.01, episode reward = 201.0
# training episode 975 of 1000 complete,  explore val = 0.01, episode reward = 218.0
# training episode 976 of 1000 complete,  explore val = 0.01, episode reward = 199.0
# training episode 977 of 1000 complete,  explore val = 0.01, episode reward = 225.0
# training episode 978 of 1000 complete,  explore val = 0.01, episode reward = 286.0
# training episode 979 of 1000 complete,  explore val = 0.01, episode reward = 323.0
# training episode 980 of 1000 complete,  explore val = 0.01, episode reward = 406.0
# training episode 981 of 1000 complete,  explore val = 0.01, episode reward = 368.0
# training episode 982 of 1000 complete,  explore val = 0.01, episode reward = 449.0
# training episode 983 of 1000 complete,  explore val = 0.01, episode reward = 340.0
# training episode 984 of 1000 complete,  explore val = 0.01, episode reward = 277.0
# training episode 985 of 1000 complete,  explore val = 0.01, episode reward = 181.0
# training episode 986 of 1000 complete,  explore val = 0.01, episode reward = 122.0
# training episode 987 of 1000 complete,  explore val = 0.01, episode reward = 172.0
# training episode 988 of 1000 complete,  explore val = 0.01, episode reward = 109.0
# training episode 989 of 1000 complete,  explore val = 0.01, episode reward = 226.0
# training episode 990 of 1000 complete,  explore val = 0.01, episode reward = 105.0
# training episode 991 of 1000 complete,  explore val = 0.01, episode reward = 280.0
# training episode 992 of 1000 complete,  explore val = 0.01, episode reward = 114.0
# training episode 993 of 1000 complete,  explore val = 0.01, episode reward = 264.0
# training episode 994 of 1000 complete,  explore val = 0.01, episode reward = 154.0
# training episode 995 of 1000 complete,  explore val = 0.01, episode reward = 283.0
# training episode 996 of 1000 complete,  explore val = 0.01, episode reward = 256.0
# training episode 997 of 1000 complete,  explore val = 0.01, episode reward = 220.0
# training episode 998 of 1000 complete,  explore val = 0.01, episode reward = 123.0
# training episode 999 of 1000 complete,  explore val = 0.01, episode reward = 144.0
# training episode 1000 of 1000 complete,  explore val = 0.01, episode reward = 141.0
# q-learning algorithm complete

# %% [markdown]
# # plot total episode reward history

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_reward_history(logname,**kwargs):
    # load in total episode reward history
    data = np.loadtxt(logname)
    ave = [data[v] for v in range(100)]
    
    for i in range(0,np.size(data)-100):
        m = np.mean(data[i:i+100])
        ave.append(m)
    
    # create figure
    fig = plt.figure(figsize = (12,8))
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,1,2)

    # plot total reward history
    start = 0
    if 'start' in kwargs:
        start = kwargs['start']
    ax1.plot(data[start:])
    ax1.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax1.set_ylabel('total reward',fontsize = 13)
    
    ax2.plot(ave[start:],linewidth=3)
    ax2.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax2.set_ylabel('ave total reward',fontsize=13)
    plt.show()

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plot_reward_history(reward_logname)

# %% [markdown]
# # produce animation of validation run

# %%
# load in weights
infile = demo.weight_name
with open(infile, 'rb') as in_strm:
    datastruct = pickle.load(in_strm)
