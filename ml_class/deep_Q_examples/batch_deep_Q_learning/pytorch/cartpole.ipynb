# %%
import numpy as np
import copy
import os
import pickle
import torch
from torch.autograd import Variable

'''
PyTorch does not the same abstract API Keras does for optimization, in particular
while it does contain an array of advanced first order methods like e.g., RMSprop
one needs to construct one's own looping structure in order to employ it properly. 
Below the class My_Opt does just this.  
'''
class My_Opt:
    def __init__(self,model,cost):
        self.model = model
        self.cost = cost
        learning_rate = 10**(-2)
        self.optimizer = torch.optim.RMSprop(model.parameters(), lr=learning_rate)
        
        # record history
        self.cost_history = []
        self.weight_history = []
        
    def fit(self,x,y,max_its,lr):
        # update learning rate
        self.optimizer.param_groups[0]['lr'] = lr
        
        for t in range(max_its):
            # Forward pass: compute predicted y by passing x to the model.
            y_pred = self.model(x.float())

            # Compute and print loss.
            cost_val = self.cost(y_pred, y.float())
            self.optimizer.zero_grad()

            if len(self.cost_history) == 0 or t > 0:
                # store weight and cost history
                self.cost_history.append(cost_val.data.item())
                self.weight_history.append(self.optimizer.param_groups[0]['params'])

            # Backward pass: compute gradient of the loss with respect to model
            # parameters
            cost_val.backward()

            # Calling the step function on an Optimizer makes an update to its
            # parameters
            self.optimizer.step()

        # collect last input / weights
        y_pred = self.model(x.float())
        cost_val = self.cost(y_pred, y.float())
        self.cost_history.append(cost_val.data.item())
        self.weight_history.append(self.optimizer.param_groups[0]['params'])

class QLearner():
    # load in simulator, initialize global variables
    def __init__(self,simulator,savename,**kwargs):
        # make simulator global
        self.simulator = simulator
        
        # Q learn params
        self.explore_val = 1
        self.explore_decay = 0.99
        self.num_episodes = 500        
        self.gamma = 1
        
        if "gamma" in kwargs:   
            self.gamma = args['gamma']
        if 'explore_val' in kwargs:
            self.explore_val = kwargs['explore_val']
        if 'explore_decay' in kwargs:
            self.explore_decay = kwargs['explore_decay']
        if 'num_episodes' in kwargs:
            self.num_episodes = kwargs['num_episodes']
            
        # other training variables
        self.num_actions = self.simulator.action_space.n
        state = self.simulator.reset()    
        self.state_dim = np.size(state)
        self.training_reward = []
        
        # setup memory params
        self.memory_length = 10     # length of memory replay (in episodes)
        self.episode_update = 1     # when to update (in episodes)
        self.memory = []
        if 'memory_length' in kwargs:
            self.memory_length = kwargs['memory_length']
        if 'episode_update' in kwargs:
            self.episode_update = kwargs['episode_update']
            
        ### initialize logs ###
        # create text file for training log
        self.logname = 'training_logs/' + savename + '.txt'
        self.reward_logname = 'reward_logs/' + savename + '.txt'
        self.weight_name = 'saved_model_weights/' + savename + '.pkl' 
        self.model_name = 'models/' + savename + '.json'

        self.init_log(self.logname)
        self.init_log(self.reward_logname)
        self.init_log(self.weight_name)
        self.init_log(self.model_name)
     
    ##### logging functions #####
    def init_log(self,logname):
        # delete log if old version exists
        if os.path.exists(logname): 
            os.remove(logname)
            
    def update_log(self,logname,update):
        if type(update) == str:
            logfile = open(logname, "a")
            logfile.write(update)
            logfile.close() 
        else:
            weights = []
            if os.path.exists(logname):
                with open(logname,'rb') as rfp: 
                    weights = pickle.load(rfp)
            weights.append(update)

            with open(logname,'wb') as wfp:
                pickle.dump(weights, wfp)
    
    ##### functions for creating / updating Q #####
    def initialize_Q(self,**kwargs):
        # default parameters for network
        layer_sizes = [10,10]      # two hidden layers, 10 units each, by default
        activation = 'relu'
        if 'layer_sizes' in kwargs:
            layer_sizes = kwargs['layer_sizes']
        if 'activation' in kwargs:
            activation = kwargs['activation']

        # default parameters for optimizer - reset by hand
        loss = 'mse'
        self.lr = 10**(-2)
        if 'alpha' in kwargs:
            self.lr = kwargs['alpha']

        # input / output sizes of network
        input_dim = self.state_dim
        output_dim = self.num_actions

        # Use the nn package to define our model and loss function
        self.model = torch.nn.Sequential()

        # add input layer
        self.model.add_module('linear ' + str(0),torch.nn.Linear(input_dim,layer_sizes[0]))
        if activation == 'relu':
            self.model.add_module('activation ' + str(0),torch.nn.ReLU())
        if activation == 'tanh':
            self.model.add_module('activation ' + str(0),torch.nn.Tanh())

        # add hidden layers
        for i in range(1,len(layer_sizes)):
            U = layer_sizes[i-1]
            V = layer_sizes[i]
            self.model.add_module('linear ' + str(i),torch.nn.Linear(U,V))
            if activation == 'relu':
                self.model.add_module('activation ' + str(i),torch.nn.ReLU())
            if activation == 'tanh':
                self.model.add_module('activation ' + str(i),torch.nn.Tanh())

        # add output layer
        self.model.add_module('linear ' + str(len(layer_sizes)),torch.nn.Linear(layer_sizes[-1], output_dim))

        # define cost function
        self.cost = torch.nn.MSELoss(size_average=True)
        
        # setup optimizer - using hand-made optimizer class + RMSprop
        self.opt = My_Opt(self.model,self.cost)

        # initialize Q
        self.Q = self.opt.model.forward

    # update Q function
    def update_Q(self):        
        # generate q_values based on most recent Q
        q_vals = []
        states = []
        for i in range(len(self.memory)):    
            # get episode_data
            episode_data = self.memory[i]
            
            # loop over episode data and create input/output pairs
            for j in range(len(episode_data)):
                # get next sample of episode
                sample = episode_data[j]
            
                # strip sample for parts
                state = sample[0]
                next_state = sample[1]
                action = sample[2]
                reward = sample[3]
                done = sample[4]

                ### for cartpole only - check if done, and alter reward to improve learning ###
                done,reward = self.check_done(done,reward)

                # compute and store q value
                q = reward 
                if done == False:
                    next_state = Variable(torch.from_numpy(next_state),requires_grad=False)        
                    qs = self.Q(next_state.float()).detach().numpy()
                    q += self.gamma*np.max(qs)

                # clamp all other models to their current values for this input/output pair
                state = Variable(torch.from_numpy(state),requires_grad=False)        
                q_update = self.Q(state.float()).detach().numpy().flatten()
                q_update[action] = q
                q_vals.append(q_update)
                states.append(state.numpy().flatten())

        # convert lists to numpy arrays for regressor
        states = np.array(states).T
        states = torch.from_numpy(states)
        s_in = Variable(states,requires_grad = False)
        q_vals = np.array(q_vals).T
        q_vals = torch.from_numpy(q_vals)
        q_vals = Variable(q_vals,requires_grad = False)

        # take descent step
        self.opt.fit(s_in.t(),q_vals.t(),max_its = 1,lr=self.lr)

        # update Q based on regressor updates
        self.Q = self.opt.model.forward
        
    ##### functions for adjusting replay memory #####
    # update memory - add sample to list, remove oldest samples 
    def update_memory(self,episode_data):
        # add most recent trial data to memory
        self.memory.append(episode_data)

        # clip memory if it gets too long    
        num_episodes = len(self.memory)
        if num_episodes >= self.memory_length:    
            num_delete = num_episodes - self.memory_length
            self.memory[:num_delete] = []
    
    ##### Q Learning functionality #####
    # special function to check done
    def check_done(self,done,reward):
        if done == True:
            reward = -100
        return done,reward
    
    # state normalizer
    def state_normalizer(self,states):
        states = np.array(states)[np.newaxis,:]
        return states
    
    # choose next action
    def choose_action(self,state):
        # pick action at random
        p = np.random.rand(1)   
        action = np.random.randint(self.num_actions)
            
        # pick action based on exploiting - after memory full
        state = Variable(torch.from_numpy(state),requires_grad=False)        
        qs = self.Q(state.float()).detach().numpy()
        if p > self.explore_val:
            action = np.argmax(qs)
        return action
    
    # main training function
    def train(self,**kwargs):
        
        ### start main Q-learning loop ###
        for n in range(self.num_episodes): 
            # pick this episode's starting position - randomly initialize from f_system
            state = self.simulator.reset()    
            state = self.state_normalizer(state)
            total_episode_reward = 0
            done = False
            
            # get out exploit parameter for this episode
            if self.explore_val > 0.01:
                self.explore_val *= self.explore_decay
                    
            # run episode
            step = 0
            episode_data = []
            while done == False and step < 500:    
                # choose next action
                action = self.choose_action(state)
    
                # transition to next state, get associated reward
                next_state,reward,done,info = self.simulator.step(action)  
                next_state = self.state_normalizer(next_state)
                
                # store data for transition after episode ends
                episode_data.append([state,next_state,action,reward,done])

                # update total reward from this episode
                total_episode_reward+=reward
                state = copy.deepcopy(next_state)
                step += 1
                  
            # update memory with this episode's data
            self.update_memory(episode_data)
            
            # update Q function
            if np.mod(n,self.episode_update) == 0:
                self.update_Q()  
                  
            ### print out updates ###
            update = 'training episode ' + str(n+1) +  ' of ' + str(self.num_episodes) + ' complete, ' +  ' explore val = ' + str(np.round(self.explore_val,3)) + ', episode reward = ' + str(np.round(total_episode_reward,2)) 

            self.update_log(self.logname,update + '\n')
            print (update)

            update = str(total_episode_reward) + '\n'
            self.update_log(self.reward_logname,update)

            ### store this episode's computation time and training reward history
            self.training_reward.append(total_episode_reward)

            # save latest weights from this episode 
            update = self.opt.weight_history[-1]
            self.update_log(self.weight_name,update)
                            
        ### save weights ###
        update = 'q-learning algorithm complete'
        self.update_log(self.logname,update + '\n')
        print (update)

# %% [markdown]
# # Run test

# %%
# imports
import gym

# savename
savename = 'cartpole_experiment_1'

# initialize simulator
simulator = gym.make('CartPole-v1') 

# initialize Q Learn process
num_episodes = 500
explore_decay = 1
explore_val = 0.01

# initialize memory
episode_update = 1
memory_length = 5

# load into instance of learner
demo = QLearner(simulator,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,episode_update=episode_update)

# initialize Q function
layer_sizes = [50,50]
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
demo.train()
# Out:
# training episode 1 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 2 of 500 complete,  explore val = 0.01, episode reward = 16.0
# training episode 3 of 500 complete,  explore val = 0.01, episode reward = 67.0
# training episode 4 of 500 complete,  explore val = 0.01, episode reward = 40.0
# training episode 5 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 6 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 7 of 500 complete,  explore val = 0.01, episode reward = 33.0
# training episode 8 of 500 complete,  explore val = 0.01, episode reward = 61.0
# training episode 9 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 10 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 11 of 500 complete,  explore val = 0.01, episode reward = 39.0
# training episode 12 of 500 complete,  explore val = 0.01, episode reward = 302.0
# training episode 13 of 500 complete,  explore val = 0.01, episode reward = 50.0
# training episode 14 of 500 complete,  explore val = 0.01, episode reward = 129.0
# training episode 15 of 500 complete,  explore val = 0.01, episode reward = 62.0
# training episode 16 of 500 complete,  explore val = 0.01, episode reward = 54.0
# training episode 17 of 500 complete,  explore val = 0.01, episode reward = 50.0
# training episode 18 of 500 complete,  explore val = 0.01, episode reward = 241.0
# training episode 19 of 500 complete,  explore val = 0.01, episode reward = 241.0
# training episode 20 of 500 complete,  explore val = 0.01, episode reward = 287.0
# training episode 21 of 500 complete,  explore val = 0.01, episode reward = 56.0
# training episode 22 of 500 complete,  explore val = 0.01, episode reward = 147.0
# training episode 23 of 500 complete,  explore val = 0.01, episode reward = 120.0
# training episode 24 of 500 complete,  explore val = 0.01, episode reward = 287.0
# training episode 25 of 500 complete,  explore val = 0.01, episode reward = 177.0
# training episode 26 of 500 complete,  explore val = 0.01, episode reward = 55.0
# training episode 27 of 500 complete,  explore val = 0.01, episode reward = 73.0
# training episode 28 of 500 complete,  explore val = 0.01, episode reward = 49.0
# training episode 29 of 500 complete,  explore val = 0.01, episode reward = 54.0
# training episode 30 of 500 complete,  explore val = 0.01, episode reward = 104.0
# training episode 31 of 500 complete,  explore val = 0.01, episode reward = 92.0
# training episode 32 of 500 complete,  explore val = 0.01, episode reward = 63.0
# training episode 33 of 500 complete,  explore val = 0.01, episode reward = 61.0
# training episode 34 of 500 complete,  explore val = 0.01, episode reward = 32.0
# training episode 35 of 500 complete,  explore val = 0.01, episode reward = 46.0
# training episode 36 of 500 complete,  explore val = 0.01, episode reward = 42.0
# training episode 37 of 500 complete,  explore val = 0.01, episode reward = 79.0
# training episode 38 of 500 complete,  explore val = 0.01, episode reward = 20.0
# training episode 39 of 500 complete,  explore val = 0.01, episode reward = 24.0
# training episode 40 of 500 complete,  explore val = 0.01, episode reward = 32.0
# training episode 41 of 500 complete,  explore val = 0.01, episode reward = 51.0
# training episode 42 of 500 complete,  explore val = 0.01, episode reward = 73.0
# training episode 43 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 44 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 45 of 500 complete,  explore val = 0.01, episode reward = 340.0
# training episode 46 of 500 complete,  explore val = 0.01, episode reward = 122.0
# training episode 47 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 48 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 49 of 500 complete,  explore val = 0.01, episode reward = 104.0
# training episode 50 of 500 complete,  explore val = 0.01, episode reward = 138.0
# training episode 51 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 52 of 500 complete,  explore val = 0.01, episode reward = 277.0
# training episode 53 of 500 complete,  explore val = 0.01, episode reward = 87.0
# training episode 54 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 55 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 56 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 57 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 58 of 500 complete,  explore val = 0.01, episode reward = 206.0
# training episode 59 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 60 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 61 of 500 complete,  explore val = 0.01, episode reward = 229.0
# training episode 62 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 63 of 500 complete,  explore val = 0.01, episode reward = 212.0
# training episode 64 of 500 complete,  explore val = 0.01, episode reward = 78.0
# training episode 65 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 66 of 500 complete,  explore val = 0.01, episode reward = 239.0
# training episode 67 of 500 complete,  explore val = 0.01, episode reward = 402.0
# training episode 68 of 500 complete,  explore val = 0.01, episode reward = 53.0
# training episode 69 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 70 of 500 complete,  explore val = 0.01, episode reward = 102.0
# training episode 71 of 500 complete,  explore val = 0.01, episode reward = 91.0
# training episode 72 of 500 complete,  explore val = 0.01, episode reward = 207.0
# training episode 73 of 500 complete,  explore val = 0.01, episode reward = 78.0
# training episode 74 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 75 of 500 complete,  explore val = 0.01, episode reward = 40.0
# training episode 76 of 500 complete,  explore val = 0.01, episode reward = 228.0
# training episode 77 of 500 complete,  explore val = 0.01, episode reward = 39.0
# training episode 78 of 500 complete,  explore val = 0.01, episode reward = 77.0
# training episode 79 of 500 complete,  explore val = 0.01, episode reward = 37.0
# training episode 80 of 500 complete,  explore val = 0.01, episode reward = 68.0
# training episode 81 of 500 complete,  explore val = 0.01, episode reward = 39.0
# training episode 82 of 500 complete,  explore val = 0.01, episode reward = 80.0
# training episode 83 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 84 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 85 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 86 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 87 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 88 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 89 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 90 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 91 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 92 of 500 complete,  explore val = 0.01, episode reward = 273.0
# training episode 93 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 94 of 500 complete,  explore val = 0.01, episode reward = 226.0
# training episode 95 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 96 of 500 complete,  explore val = 0.01, episode reward = 182.0
# training episode 97 of 500 complete,  explore val = 0.01, episode reward = 76.0
# training episode 98 of 500 complete,  explore val = 0.01, episode reward = 129.0
# training episode 99 of 500 complete,  explore val = 0.01, episode reward = 8.0
# training episode 100 of 500 complete,  explore val = 0.01, episode reward = 165.0
# training episode 101 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 102 of 500 complete,  explore val = 0.01, episode reward = 12.0
# training episode 103 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 104 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 105 of 500 complete,  explore val = 0.01, episode reward = 18.0
# training episode 106 of 500 complete,  explore val = 0.01, episode reward = 20.0
# training episode 107 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 108 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 109 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 110 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 111 of 500 complete,  explore val = 0.01, episode reward = 13.0
# training episode 112 of 500 complete,  explore val = 0.01, episode reward = 15.0
# training episode 113 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 114 of 500 complete,  explore val = 0.01, episode reward = 15.0
# training episode 115 of 500 complete,  explore val = 0.01, episode reward = 9.0
# training episode 116 of 500 complete,  explore val = 0.01, episode reward = 19.0
# training episode 117 of 500 complete,  explore val = 0.01, episode reward = 14.0
# training episode 118 of 500 complete,  explore val = 0.01, episode reward = 9.0
# training episode 119 of 500 complete,  explore val = 0.01, episode reward = 25.0
# training episode 120 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 121 of 500 complete,  explore val = 0.01, episode reward = 39.0
# training episode 122 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 123 of 500 complete,  explore val = 0.01, episode reward = 144.0
# training episode 124 of 500 complete,  explore val = 0.01, episode reward = 173.0
# training episode 125 of 500 complete,  explore val = 0.01, episode reward = 186.0
# training episode 126 of 500 complete,  explore val = 0.01, episode reward = 216.0
# training episode 127 of 500 complete,  explore val = 0.01, episode reward = 229.0
# training episode 128 of 500 complete,  explore val = 0.01, episode reward = 266.0
# training episode 129 of 500 complete,  explore val = 0.01, episode reward = 219.0
# training episode 130 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 131 of 500 complete,  explore val = 0.01, episode reward = 178.0
# training episode 132 of 500 complete,  explore val = 0.01, episode reward = 231.0
# training episode 133 of 500 complete,  explore val = 0.01, episode reward = 218.0
# training episode 134 of 500 complete,  explore val = 0.01, episode reward = 229.0
# training episode 135 of 500 complete,  explore val = 0.01, episode reward = 186.0
# training episode 136 of 500 complete,  explore val = 0.01, episode reward = 261.0
# training episode 137 of 500 complete,  explore val = 0.01, episode reward = 214.0
# training episode 138 of 500 complete,  explore val = 0.01, episode reward = 406.0
# training episode 139 of 500 complete,  explore val = 0.01, episode reward = 163.0
# training episode 140 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 141 of 500 complete,  explore val = 0.01, episode reward = 158.0
# training episode 142 of 500 complete,  explore val = 0.01, episode reward = 247.0
# training episode 143 of 500 complete,  explore val = 0.01, episode reward = 178.0
# training episode 144 of 500 complete,  explore val = 0.01, episode reward = 206.0
# training episode 145 of 500 complete,  explore val = 0.01, episode reward = 181.0
# training episode 146 of 500 complete,  explore val = 0.01, episode reward = 199.0
# training episode 147 of 500 complete,  explore val = 0.01, episode reward = 169.0
# training episode 148 of 500 complete,  explore val = 0.01, episode reward = 279.0
# training episode 149 of 500 complete,  explore val = 0.01, episode reward = 207.0
# training episode 150 of 500 complete,  explore val = 0.01, episode reward = 301.0
# training episode 151 of 500 complete,  explore val = 0.01, episode reward = 153.0
# training episode 152 of 500 complete,  explore val = 0.01, episode reward = 442.0
# training episode 153 of 500 complete,  explore val = 0.01, episode reward = 146.0
# training episode 154 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 155 of 500 complete,  explore val = 0.01, episode reward = 152.0
# training episode 156 of 500 complete,  explore val = 0.01, episode reward = 206.0
# training episode 157 of 500 complete,  explore val = 0.01, episode reward = 171.0
# training episode 158 of 500 complete,  explore val = 0.01, episode reward = 173.0
# training episode 159 of 500 complete,  explore val = 0.01, episode reward = 188.0
# training episode 160 of 500 complete,  explore val = 0.01, episode reward = 184.0
# training episode 161 of 500 complete,  explore val = 0.01, episode reward = 249.0
# training episode 162 of 500 complete,  explore val = 0.01, episode reward = 199.0
# training episode 163 of 500 complete,  explore val = 0.01, episode reward = 233.0
# training episode 164 of 500 complete,  explore val = 0.01, episode reward = 166.0
# training episode 165 of 500 complete,  explore val = 0.01, episode reward = 285.0
# training episode 166 of 500 complete,  explore val = 0.01, episode reward = 133.0
# training episode 167 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 168 of 500 complete,  explore val = 0.01, episode reward = 117.0
# training episode 169 of 500 complete,  explore val = 0.01, episode reward = 275.0
# training episode 170 of 500 complete,  explore val = 0.01, episode reward = 200.0
# training episode 171 of 500 complete,  explore val = 0.01, episode reward = 182.0
# training episode 172 of 500 complete,  explore val = 0.01, episode reward = 217.0
# training episode 173 of 500 complete,  explore val = 0.01, episode reward = 292.0
# training episode 174 of 500 complete,  explore val = 0.01, episode reward = 203.0
# training episode 175 of 500 complete,  explore val = 0.01, episode reward = 249.0
# training episode 176 of 500 complete,  explore val = 0.01, episode reward = 255.0
# training episode 177 of 500 complete,  explore val = 0.01, episode reward = 404.0
# training episode 178 of 500 complete,  explore val = 0.01, episode reward = 187.0
# training episode 179 of 500 complete,  explore val = 0.01, episode reward = 429.0
# training episode 180 of 500 complete,  explore val = 0.01, episode reward = 149.0
# training episode 181 of 500 complete,  explore val = 0.01, episode reward = 393.0
# training episode 182 of 500 complete,  explore val = 0.01, episode reward = 159.0
# training episode 183 of 500 complete,  explore val = 0.01, episode reward = 255.0
# training episode 184 of 500 complete,  explore val = 0.01, episode reward = 180.0
# training episode 185 of 500 complete,  explore val = 0.01, episode reward = 325.0
# training episode 186 of 500 complete,  explore val = 0.01, episode reward = 239.0
# training episode 187 of 500 complete,  explore val = 0.01, episode reward = 242.0
# training episode 188 of 500 complete,  explore val = 0.01, episode reward = 170.0
# training episode 189 of 500 complete,  explore val = 0.01, episode reward = 483.0
# training episode 190 of 500 complete,  explore val = 0.01, episode reward = 148.0
# training episode 191 of 500 complete,  explore val = 0.01, episode reward = 470.0
# training episode 192 of 500 complete,  explore val = 0.01, episode reward = 151.0
# training episode 193 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 194 of 500 complete,  explore val = 0.01, episode reward = 206.0
# training episode 195 of 500 complete,  explore val = 0.01, episode reward = 229.0
# training episode 196 of 500 complete,  explore val = 0.01, episode reward = 187.0
# training episode 197 of 500 complete,  explore val = 0.01, episode reward = 255.0
# training episode 198 of 500 complete,  explore val = 0.01, episode reward = 260.0
# training episode 199 of 500 complete,  explore val = 0.01, episode reward = 266.0
# training episode 200 of 500 complete,  explore val = 0.01, episode reward = 262.0
# training episode 201 of 500 complete,  explore val = 0.01, episode reward = 259.0
# training episode 202 of 500 complete,  explore val = 0.01, episode reward = 351.0
# training episode 203 of 500 complete,  explore val = 0.01, episode reward = 314.0
# training episode 204 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 205 of 500 complete,  explore val = 0.01, episode reward = 206.0
# training episode 206 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 207 of 500 complete,  explore val = 0.01, episode reward = 233.0
# training episode 208 of 500 complete,  explore val = 0.01, episode reward = 306.0
# training episode 209 of 500 complete,  explore val = 0.01, episode reward = 303.0
# training episode 210 of 500 complete,  explore val = 0.01, episode reward = 387.0
# training episode 211 of 500 complete,  explore val = 0.01, episode reward = 223.0
# training episode 212 of 500 complete,  explore val = 0.01, episode reward = 305.0
# training episode 213 of 500 complete,  explore val = 0.01, episode reward = 195.0
# training episode 214 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 215 of 500 complete,  explore val = 0.01, episode reward = 178.0
# training episode 216 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 217 of 500 complete,  explore val = 0.01, episode reward = 164.0
# training episode 218 of 500 complete,  explore val = 0.01, episode reward = 416.0
# training episode 219 of 500 complete,  explore val = 0.01, episode reward = 264.0
# training episode 220 of 500 complete,  explore val = 0.01, episode reward = 423.0
# training episode 221 of 500 complete,  explore val = 0.01, episode reward = 254.0
# training episode 222 of 500 complete,  explore val = 0.01, episode reward = 496.0
# training episode 223 of 500 complete,  explore val = 0.01, episode reward = 236.0
# training episode 224 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 225 of 500 complete,  explore val = 0.01, episode reward = 211.0
# training episode 226 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 227 of 500 complete,  explore val = 0.01, episode reward = 213.0
# training episode 228 of 500 complete,  explore val = 0.01, episode reward = 450.0
# training episode 229 of 500 complete,  explore val = 0.01, episode reward = 196.0
# training episode 230 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 231 of 500 complete,  explore val = 0.01, episode reward = 215.0
# training episode 232 of 500 complete,  explore val = 0.01, episode reward = 426.0
# training episode 233 of 500 complete,  explore val = 0.01, episode reward = 196.0
# training episode 234 of 500 complete,  explore val = 0.01, episode reward = 340.0
# training episode 235 of 500 complete,  explore val = 0.01, episode reward = 215.0
# training episode 236 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 237 of 500 complete,  explore val = 0.01, episode reward = 135.0
# training episode 238 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 239 of 500 complete,  explore val = 0.01, episode reward = 183.0
# training episode 240 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 241 of 500 complete,  explore val = 0.01, episode reward = 264.0
# training episode 242 of 500 complete,  explore val = 0.01, episode reward = 476.0
# training episode 243 of 500 complete,  explore val = 0.01, episode reward = 349.0
# training episode 244 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 245 of 500 complete,  explore val = 0.01, episode reward = 288.0
# training episode 246 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 247 of 500 complete,  explore val = 0.01, episode reward = 235.0
# training episode 248 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 249 of 500 complete,  explore val = 0.01, episode reward = 219.0
# training episode 250 of 500 complete,  explore val = 0.01, episode reward = 315.0
# training episode 251 of 500 complete,  explore val = 0.01, episode reward = 200.0
# training episode 252 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 253 of 500 complete,  explore val = 0.01, episode reward = 188.0
# training episode 254 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 255 of 500 complete,  explore val = 0.01, episode reward = 182.0
# training episode 256 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 257 of 500 complete,  explore val = 0.01, episode reward = 204.0
# training episode 258 of 500 complete,  explore val = 0.01, episode reward = 437.0
# training episode 259 of 500 complete,  explore val = 0.01, episode reward = 171.0
# training episode 260 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 261 of 500 complete,  explore val = 0.01, episode reward = 176.0
# training episode 262 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 263 of 500 complete,  explore val = 0.01, episode reward = 148.0
# training episode 264 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 265 of 500 complete,  explore val = 0.01, episode reward = 167.0
# training episode 266 of 500 complete,  explore val = 0.01, episode reward = 475.0
# training episode 267 of 500 complete,  explore val = 0.01, episode reward = 224.0
# training episode 268 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 269 of 500 complete,  explore val = 0.01, episode reward = 198.0
# training episode 270 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 271 of 500 complete,  explore val = 0.01, episode reward = 216.0
# training episode 272 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 273 of 500 complete,  explore val = 0.01, episode reward = 196.0
# training episode 274 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 275 of 500 complete,  explore val = 0.01, episode reward = 182.0
# training episode 276 of 500 complete,  explore val = 0.01, episode reward = 225.0
# training episode 277 of 500 complete,  explore val = 0.01, episode reward = 164.0
# training episode 278 of 500 complete,  explore val = 0.01, episode reward = 153.0
# training episode 279 of 500 complete,  explore val = 0.01, episode reward = 102.0
# training episode 280 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 281 of 500 complete,  explore val = 0.01, episode reward = 124.0
# training episode 282 of 500 complete,  explore val = 0.01, episode reward = 271.0
# training episode 283 of 500 complete,  explore val = 0.01, episode reward = 135.0
# training episode 284 of 500 complete,  explore val = 0.01, episode reward = 311.0
# training episode 285 of 500 complete,  explore val = 0.01, episode reward = 136.0
# training episode 286 of 500 complete,  explore val = 0.01, episode reward = 362.0
# training episode 287 of 500 complete,  explore val = 0.01, episode reward = 110.0
# training episode 288 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 289 of 500 complete,  explore val = 0.01, episode reward = 109.0
# training episode 290 of 500 complete,  explore val = 0.01, episode reward = 225.0
# training episode 291 of 500 complete,  explore val = 0.01, episode reward = 157.0
# training episode 292 of 500 complete,  explore val = 0.01, episode reward = 224.0
# training episode 293 of 500 complete,  explore val = 0.01, episode reward = 192.0
# training episode 294 of 500 complete,  explore val = 0.01, episode reward = 283.0
# training episode 295 of 500 complete,  explore val = 0.01, episode reward = 179.0
# training episode 296 of 500 complete,  explore val = 0.01, episode reward = 354.0
# training episode 297 of 500 complete,  explore val = 0.01, episode reward = 133.0
# training episode 298 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 299 of 500 complete,  explore val = 0.01, episode reward = 108.0
# training episode 300 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 301 of 500 complete,  explore val = 0.01, episode reward = 155.0
# training episode 302 of 500 complete,  explore val = 0.01, episode reward = 418.0
# training episode 303 of 500 complete,  explore val = 0.01, episode reward = 198.0
# training episode 304 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 305 of 500 complete,  explore val = 0.01, episode reward = 192.0
# training episode 306 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 307 of 500 complete,  explore val = 0.01, episode reward = 153.0
# training episode 308 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 309 of 500 complete,  explore val = 0.01, episode reward = 146.0
# training episode 310 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 311 of 500 complete,  explore val = 0.01, episode reward = 169.0
# training episode 312 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 313 of 500 complete,  explore val = 0.01, episode reward = 148.0
# training episode 314 of 500 complete,  explore val = 0.01, episode reward = 252.0
# training episode 315 of 500 complete,  explore val = 0.01, episode reward = 112.0
# training episode 316 of 500 complete,  explore val = 0.01, episode reward = 118.0
# training episode 317 of 500 complete,  explore val = 0.01, episode reward = 11.0
# training episode 318 of 500 complete,  explore val = 0.01, episode reward = 137.0
# training episode 319 of 500 complete,  explore val = 0.01, episode reward = 14.0
# training episode 320 of 500 complete,  explore val = 0.01, episode reward = 29.0
# training episode 321 of 500 complete,  explore val = 0.01, episode reward = 112.0
# training episode 322 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 323 of 500 complete,  explore val = 0.01, episode reward = 21.0
# training episode 324 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 325 of 500 complete,  explore val = 0.01, episode reward = 9.0
# training episode 326 of 500 complete,  explore val = 0.01, episode reward = 15.0
# training episode 327 of 500 complete,  explore val = 0.01, episode reward = 49.0
# training episode 328 of 500 complete,  explore val = 0.01, episode reward = 11.0
# training episode 329 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 330 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 331 of 500 complete,  explore val = 0.01, episode reward = 10.0
# training episode 332 of 500 complete,  explore val = 0.01, episode reward = 41.0
# training episode 333 of 500 complete,  explore val = 0.01, episode reward = 47.0
# training episode 334 of 500 complete,  explore val = 0.01, episode reward = 332.0
# training episode 335 of 500 complete,  explore val = 0.01, episode reward = 202.0
# training episode 336 of 500 complete,  explore val = 0.01, episode reward = 307.0
# training episode 337 of 500 complete,  explore val = 0.01, episode reward = 342.0
# training episode 338 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 339 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 340 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 341 of 500 complete,  explore val = 0.01, episode reward = 424.0
# training episode 342 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 343 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 344 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 345 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 346 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 347 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 348 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 349 of 500 complete,  explore val = 0.01, episode reward = 222.0
# training episode 350 of 500 complete,  explore val = 0.01, episode reward = 195.0
# training episode 351 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 352 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 353 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 354 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 355 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 356 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 357 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 358 of 500 complete,  explore val = 0.01, episode reward = 300.0
# training episode 359 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 360 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 361 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 362 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 363 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 364 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 365 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 366 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 367 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 368 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 369 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 370 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 371 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 372 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 373 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 374 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 375 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 376 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 377 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 378 of 500 complete,  explore val = 0.01, episode reward = 387.0
# training episode 379 of 500 complete,  explore val = 0.01, episode reward = 380.0
# training episode 380 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 381 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 382 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 383 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 384 of 500 complete,  explore val = 0.01, episode reward = 394.0
# training episode 385 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 386 of 500 complete,  explore val = 0.01, episode reward = 243.0
# training episode 387 of 500 complete,  explore val = 0.01, episode reward = 396.0
# training episode 388 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 389 of 500 complete,  explore val = 0.01, episode reward = 396.0
# training episode 390 of 500 complete,  explore val = 0.01, episode reward = 325.0
# training episode 391 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 392 of 500 complete,  explore val = 0.01, episode reward = 327.0
# training episode 393 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 394 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 395 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 396 of 500 complete,  explore val = 0.01, episode reward = 365.0
# training episode 397 of 500 complete,  explore val = 0.01, episode reward = 329.0
# training episode 398 of 500 complete,  explore val = 0.01, episode reward = 255.0
# training episode 399 of 500 complete,  explore val = 0.01, episode reward = 487.0
# training episode 400 of 500 complete,  explore val = 0.01, episode reward = 341.0
# training episode 401 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 402 of 500 complete,  explore val = 0.01, episode reward = 329.0
# training episode 403 of 500 complete,  explore val = 0.01, episode reward = 471.0
# training episode 404 of 500 complete,  explore val = 0.01, episode reward = 269.0
# training episode 405 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 406 of 500 complete,  explore val = 0.01, episode reward = 234.0
# training episode 407 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 408 of 500 complete,  explore val = 0.01, episode reward = 213.0
# training episode 409 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 410 of 500 complete,  explore val = 0.01, episode reward = 182.0
# training episode 411 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 412 of 500 complete,  explore val = 0.01, episode reward = 206.0
# training episode 413 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 414 of 500 complete,  explore val = 0.01, episode reward = 275.0
# training episode 415 of 500 complete,  explore val = 0.01, episode reward = 392.0
# training episode 416 of 500 complete,  explore val = 0.01, episode reward = 300.0
# training episode 417 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 418 of 500 complete,  explore val = 0.01, episode reward = 268.0
# training episode 419 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 420 of 500 complete,  explore val = 0.01, episode reward = 166.0
# training episode 421 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 422 of 500 complete,  explore val = 0.01, episode reward = 252.0
# training episode 423 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 424 of 500 complete,  explore val = 0.01, episode reward = 251.0
# training episode 425 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 426 of 500 complete,  explore val = 0.01, episode reward = 239.0
# training episode 427 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 428 of 500 complete,  explore val = 0.01, episode reward = 250.0
# training episode 429 of 500 complete,  explore val = 0.01, episode reward = 434.0
# training episode 430 of 500 complete,  explore val = 0.01, episode reward = 283.0
# training episode 431 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 432 of 500 complete,  explore val = 0.01, episode reward = 244.0
# training episode 433 of 500 complete,  explore val = 0.01, episode reward = 345.0
# training episode 434 of 500 complete,  explore val = 0.01, episode reward = 194.0
# training episode 435 of 500 complete,  explore val = 0.01, episode reward = 469.0
# training episode 436 of 500 complete,  explore val = 0.01, episode reward = 178.0
# training episode 437 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 438 of 500 complete,  explore val = 0.01, episode reward = 165.0
# training episode 439 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 440 of 500 complete,  explore val = 0.01, episode reward = 203.0
# training episode 441 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 442 of 500 complete,  explore val = 0.01, episode reward = 210.0
# training episode 443 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 444 of 500 complete,  explore val = 0.01, episode reward = 283.0
# training episode 445 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 446 of 500 complete,  explore val = 0.01, episode reward = 248.0
# training episode 447 of 500 complete,  explore val = 0.01, episode reward = 458.0
# training episode 448 of 500 complete,  explore val = 0.01, episode reward = 208.0
# training episode 449 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 450 of 500 complete,  explore val = 0.01, episode reward = 233.0
# training episode 451 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 452 of 500 complete,  explore val = 0.01, episode reward = 199.0
# training episode 453 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 454 of 500 complete,  explore val = 0.01, episode reward = 190.0
# training episode 455 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 456 of 500 complete,  explore val = 0.01, episode reward = 204.0
# training episode 457 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 458 of 500 complete,  explore val = 0.01, episode reward = 176.0
# training episode 459 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 460 of 500 complete,  explore val = 0.01, episode reward = 191.0
# training episode 461 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 462 of 500 complete,  explore val = 0.01, episode reward = 279.0
# training episode 463 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 464 of 500 complete,  explore val = 0.01, episode reward = 244.0
# training episode 465 of 500 complete,  explore val = 0.01, episode reward = 436.0
# training episode 466 of 500 complete,  explore val = 0.01, episode reward = 250.0
# training episode 467 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 468 of 500 complete,  explore val = 0.01, episode reward = 205.0
# training episode 469 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 470 of 500 complete,  explore val = 0.01, episode reward = 181.0
# training episode 471 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 472 of 500 complete,  explore val = 0.01, episode reward = 170.0
# training episode 473 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 474 of 500 complete,  explore val = 0.01, episode reward = 234.0
# training episode 475 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 476 of 500 complete,  explore val = 0.01, episode reward = 280.0
# training episode 477 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 478 of 500 complete,  explore val = 0.01, episode reward = 243.0
# training episode 479 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 480 of 500 complete,  explore val = 0.01, episode reward = 296.0
# training episode 481 of 500 complete,  explore val = 0.01, episode reward = 430.0
# training episode 482 of 500 complete,  explore val = 0.01, episode reward = 245.0
# training episode 483 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 484 of 500 complete,  explore val = 0.01, episode reward = 242.0
# training episode 485 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 486 of 500 complete,  explore val = 0.01, episode reward = 198.0
# training episode 487 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 488 of 500 complete,  explore val = 0.01, episode reward = 201.0
# training episode 489 of 500 complete,  explore val = 0.01, episode reward = 473.0
# training episode 490 of 500 complete,  explore val = 0.01, episode reward = 197.0
# training episode 491 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 492 of 500 complete,  explore val = 0.01, episode reward = 153.0
# training episode 493 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 494 of 500 complete,  explore val = 0.01, episode reward = 179.0
# training episode 495 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 496 of 500 complete,  explore val = 0.01, episode reward = 238.0
# training episode 497 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 498 of 500 complete,  explore val = 0.01, episode reward = 267.0
# training episode 499 of 500 complete,  explore val = 0.01, episode reward = 500.0
# training episode 500 of 500 complete,  explore val = 0.01, episode reward = 206.0
# q-learning algorithm complete

# %% [markdown]
# # plot total episode reward history

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_reward_history(logname,**kwargs):
    # load in total episode reward history
    data = np.loadtxt(logname)
    ave = [data[v] for v in range(100)]
    
    for i in range(0,np.size(data)-100):
        m = np.mean(data[i:i+100])
        ave.append(m)
    
    # create figure
    fig = plt.figure(figsize = (12,8))
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,1,2)

    # plot total reward history
    start = 0
    if 'start' in kwargs:
        start = kwargs['start']
    ax1.plot(data[start:])
    ax1.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax1.set_ylabel('total reward',fontsize = 13)
    
    ax2.plot(ave[start:],linewidth=3)
    ax2.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax2.set_ylabel('ave total reward',fontsize=13)
    plt.show()

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plot_reward_history(reward_logname)

# %% [markdown]
# # produce animation of validation run

# %%
# load in weights
infile = demo.weight_name
with open(infile, 'rb') as in_strm:
    datastruct = pickle.load(in_strm)

# %%
len(datastruct)
