# %%
import numpy as np
import copy
import os
import pickle
import sys
from reinforce_lib import func_approx_library as funclib

# %load_ext autoreload
# %autoreload 2

class QLearner():
    # load in simulator, initialize global variables
    def __init__(self,simulator,savename,**kwargs):
        # make simulator global
        self.simulator = simulator
        
        # Q learn params
        self.explore_val = 1
        self.explore_decay = 0.99
        self.num_episodes = 500        
        self.gamma = 1
        
        if "gamma" in kwargs:   
            self.gamma = args['gamma']
        if 'explore_val' in kwargs:
            self.explore_val = kwargs['explore_val']
        if 'explore_decay' in kwargs:
            self.explore_decay = kwargs['explore_decay']
        if 'num_episodes' in kwargs:
            self.num_episodes = kwargs['num_episodes']
            
        # other training variables
        self.num_actions = self.simulator.action_space.n
        state = self.simulator.reset()    
        self.state_dim = np.size(state)
        self.training_reward = []
        
        # setup memory params
        self.memory_length = 2000    # length of memory replay
        self.replay_length = 200     # length of replay sample
        self.memory_start = 1000
        self.memory = []
        if 'memory_length' in kwargs:
            self.memory_length = kwargs['memory_length']
        if 'replay_length' in kwargs:
            self.replay_length = kwargs['replay_length']
        if 'memory_start' in kwargs:
            self.memory_start = kwargs['memory_start']
            
        ### initialize logs ###
        # create text file for training log
        self.logname = 'training_logs/' + savename + '.txt'
        self.reward_logname = 'reward_logs/' + savename + '.txt'
        self.weight_name = 'saved_model_weights/' + savename + '.pkl' 
        self.model_name = 'models/' + savename + '.json'

        self.init_log(self.logname)
        self.init_log(self.reward_logname)
        self.init_log(self.weight_name)
        self.init_log(self.model_name)
     
    ##### logging functions #####
    def init_log(self,logname):
        # delete log if old version exists
        if os.path.exists(logname): 
            os.remove(logname)
            
    def update_log(self,logname,update):
        if type(update) == str:
            logfile = open(logname, "a")
            logfile.write(update)
            logfile.close() 
        else:
            weights = []
            if os.path.exists(logname):
                with open(logname,'rb') as rfp: 
                    weights = pickle.load(rfp)
            weights.append(update)

            with open(logname,'wb') as wfp:
                pickle.dump(weights, wfp)
    
    ##### functions for creating / updating Q #####
    def initialize_Q(self,**kwargs):
        # default parameters for network
        layer_sizes = [10,10]      # two hidden layers, 10 units each, by default
        activation = 'relu'
        if 'layer_sizes' in kwargs:
            layer_sizes = kwargs['layer_sizes']
        if 'activation' in kwargs:
            activation = kwargs['activation']

        # default parameters for optimizer - reset by hand
        loss = 'mse'
        self.lr = 10**(-2)
        if 'alpha' in kwargs:
            self.lr = kwargs['alpha']

        # input / output sizes of network
        input_dim = self.state_dim
        output_dim = self.num_actions
    
        # setup network
        layer_sizes.insert(0,input_dim)
        layer_sizes.append(output_dim)

        # setup architecture, choose cost, and setup architecture
        self.model = funclib.super_setup.Setup()
        self.model.choose_cost(name = 'least_squares')
        self.model.choose_features(layer_sizes = layer_sizes,activation = activation)
            
        # initialize Q
        self.Q = self.model.predict

    # update Q function
    def update_Q(self,state,next_state,action,reward,done):
        # add newest sample to queue
        self.update_memory(state,next_state,action,reward,done)
        
        # only update Q if sufficient memory has been collected
        if len(self.memory) < self.memory_start:
            return        
        
        # update memory sample
        self.sample_memory()
        
        # generate q_values based on most recent Q
        q_vals = []
        states = []
        for i in range(len(self.replay_samples)):    
            # get sample
            sample = self.replay_samples[i]
            
            # strip sample for parts
            state = sample[0]
            next_state = sample[1]
            action = sample[2]
            reward = sample[3]
            done = sample[4]
                            
            ### for cartpole only - check if done, and alter reward to improve learning ###
            done,reward = self.check_done(done,reward)

            # compute and store q value
            q = reward 
            if done == False:
                qs = self.Q(next_state.T)
                q += self.gamma*np.max(qs)
            
            # clamp all other models to their current values for this input/output pair
            q_update = self.Q(state.T).flatten()
            q_update[action] = q
            q_vals.append(q_update)
            states.append(state.T)
            
        # convert lists to numpy arrays for regressor
        s_in = np.array(states).T
        q_vals = np.array(q_vals).T
        s_in = s_in[0,:,:]
                            
        # take descent step
        self.model.fit(s_in,q_vals,algo = 'RMSprop',max_its = 1,alpha = self.lr,verbose = False)
        
        # update Q based on regressor updates
        self.Q = self.model.predict
        
    ##### functions for adjusting replay memory #####
    # update memory - add sample to list, remove oldest samples 
    def update_memory(self,state,next_state,action,reward,done):
        # add most recent trial data to memory
        self.memory.append([state,next_state,action,reward,done])

        # clip memory if it gets too long    
        num_elements = len(self.memory)
        if num_elements >= self.memory_length:    
            num_delete = num_elements - self.memory_length
            self.memory[:num_delete] = []
    
    # sample from memory and create input / output pairs for regression
    def sample_memory(self):
        # indices to sample
        memory_num = len(self.memory)
        sample_nums = np.random.permutation(memory_num)[:self.replay_length]

        # create samples
        self.replay_samples = [self.memory[v] for v in sample_nums]
    
    ##### Q Learning functionality #####
    # state normalizer
    def state_normalizer(self,states):
        states = np.array(states)[np.newaxis,:]
        return states
    
    # choose next action
    def choose_action(self,state):
        # pick action at random
        p = np.random.rand(1)   
        action = np.random.randint(self.num_actions)
            
        # pick action based on exploiting
        if len(self.memory) >= self.memory_start:
            qs = self.Q(state.T) 
            if p > self.explore_val:
                action = np.argmax(qs)
        return action

    # special function to check done
    def check_done(self,done,reward):
        if done == True:
            reward = -100
        return done,reward
    
    # main training function
    def train(self,**kwargs):        
        ### start main Q-learning loop ###
        for n in range(self.num_episodes): 
            # pick this episode's starting position - randomly initialize from f_system
            state = self.simulator.reset()    
            state = self.state_normalizer(state)
            total_episode_reward = 0
            done = False
            
            # get out exploit parameter for this episode
            if self.explore_val > 0.01:
                self.explore_val *= self.explore_decay
                    
            # run episode
            step = 0
            while done == False and step < 500:    
                # choose next action
                action = self.choose_action(state)
    
                # transition to next state, get associated reward
                next_state,reward,done,info = self.simulator.step(action)  
                next_state = self.state_normalizer(next_state)
                
                # update Q function
                self.update_Q(state,next_state,action,reward,done)  

                # update total reward from this episode
                total_episode_reward+=reward
                state = copy.deepcopy(next_state)
                step+=1
                  
            # start storing once memory is full 
            if len(self.memory) >= self.memory_start:
                # print out update if verbose set to True
                update = 'training episode ' + str(n+1) +  ' of ' + str(self.num_episodes) + ' complete, ' +  ' explore val = ' + str(np.round(self.explore_val,3)) + ', episode reward = ' + str(np.round(total_episode_reward,2)) 

                self.update_log(self.logname,update + '\n')
                print (update)

                update = str(total_episode_reward) + '\n'
                self.update_log(self.reward_logname,update)

                ### store this episode's computation time and training reward history
                self.training_reward.append(total_episode_reward)

                # save latest weights from this episode 
                update = self.model.weight_history[-1]
                self.update_log(self.weight_name,update)
            
        ### save weights ###
        update = 'q-learning algorithm complete'
        self.update_log(self.logname,update + '\n')
        print (update)

# %% [markdown]
# # Run test

# %%
# imports
import gym

# savename
savename = 'cartpole_experiment_1'

# initialize simulator
simulator = gym.make('CartPole-v1') 

# initialize Q Learn process
num_episodes = 250
explore_decay = 0.995
explore_val = 1

# initialize memory
replay_length = 100
memory_length = 1000

# load into instance of learner
demo = QLearner(simulator,savename,num_episodes=num_episodes,explore_decay=explore_decay,explore_val=explore_val,memory_length=memory_length,replay_length=replay_length)

# initialize Q function
layer_sizes = [25,25]
alpha = 10**(-2)
activation = 'relu'
demo.initialize_Q(layer_sizes=layer_sizes,alpha=alpha,activation=activation)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
demo.train()
# Out:
# training episode 44 of 250 complete,  explore val = 0.802, episode reward = 41.0
# training episode 45 of 250 complete,  explore val = 0.798, episode reward = 16.0
# training episode 46 of 250 complete,  explore val = 0.794, episode reward = 23.0
# training episode 47 of 250 complete,  explore val = 0.79, episode reward = 18.0
# training episode 48 of 250 complete,  explore val = 0.786, episode reward = 12.0
# training episode 49 of 250 complete,  explore val = 0.782, episode reward = 35.0
# training episode 50 of 250 complete,  explore val = 0.778, episode reward = 12.0
# training episode 51 of 250 complete,  explore val = 0.774, episode reward = 22.0
# training episode 52 of 250 complete,  explore val = 0.771, episode reward = 24.0
# training episode 53 of 250 complete,  explore val = 0.767, episode reward = 49.0
# training episode 54 of 250 complete,  explore val = 0.763, episode reward = 13.0
# training episode 55 of 250 complete,  explore val = 0.759, episode reward = 17.0
# training episode 56 of 250 complete,  explore val = 0.755, episode reward = 17.0
# training episode 57 of 250 complete,  explore val = 0.751, episode reward = 128.0
# training episode 58 of 250 complete,  explore val = 0.748, episode reward = 41.0
# training episode 59 of 250 complete,  explore val = 0.744, episode reward = 97.0
# training episode 60 of 250 complete,  explore val = 0.74, episode reward = 40.0
# training episode 61 of 250 complete,  explore val = 0.737, episode reward = 53.0
# training episode 62 of 250 complete,  explore val = 0.733, episode reward = 15.0
# training episode 63 of 250 complete,  explore val = 0.729, episode reward = 30.0
# training episode 64 of 250 complete,  explore val = 0.726, episode reward = 41.0
# training episode 65 of 250 complete,  explore val = 0.722, episode reward = 40.0
# training episode 66 of 250 complete,  explore val = 0.718, episode reward = 44.0
# training episode 67 of 250 complete,  explore val = 0.715, episode reward = 13.0
# training episode 68 of 250 complete,  explore val = 0.711, episode reward = 17.0
# training episode 69 of 250 complete,  explore val = 0.708, episode reward = 22.0
# training episode 70 of 250 complete,  explore val = 0.704, episode reward = 24.0
# training episode 71 of 250 complete,  explore val = 0.701, episode reward = 56.0
# training episode 72 of 250 complete,  explore val = 0.697, episode reward = 25.0
# training episode 73 of 250 complete,  explore val = 0.694, episode reward = 49.0
# training episode 74 of 250 complete,  explore val = 0.69, episode reward = 54.0
# training episode 75 of 250 complete,  explore val = 0.687, episode reward = 11.0
# training episode 76 of 250 complete,  explore val = 0.683, episode reward = 74.0
# training episode 77 of 250 complete,  explore val = 0.68, episode reward = 71.0
# training episode 78 of 250 complete,  explore val = 0.676, episode reward = 79.0
# training episode 79 of 250 complete,  explore val = 0.673, episode reward = 25.0
# training episode 80 of 250 complete,  explore val = 0.67, episode reward = 93.0
# training episode 81 of 250 complete,  explore val = 0.666, episode reward = 38.0
# training episode 82 of 250 complete,  explore val = 0.663, episode reward = 66.0
# training episode 83 of 250 complete,  explore val = 0.66, episode reward = 26.0
# training episode 84 of 250 complete,  explore val = 0.656, episode reward = 117.0
# training episode 85 of 250 complete,  explore val = 0.653, episode reward = 98.0
# training episode 86 of 250 complete,  explore val = 0.65, episode reward = 23.0
# training episode 87 of 250 complete,  explore val = 0.647, episode reward = 18.0
# training episode 88 of 250 complete,  explore val = 0.643, episode reward = 92.0
# training episode 89 of 250 complete,  explore val = 0.64, episode reward = 73.0
# training episode 90 of 250 complete,  explore val = 0.637, episode reward = 118.0
# training episode 91 of 250 complete,  explore val = 0.634, episode reward = 43.0
# training episode 92 of 250 complete,  explore val = 0.631, episode reward = 144.0
# training episode 93 of 250 complete,  explore val = 0.627, episode reward = 40.0
# training episode 94 of 250 complete,  explore val = 0.624, episode reward = 135.0
# training episode 95 of 250 complete,  explore val = 0.621, episode reward = 25.0
# training episode 96 of 250 complete,  explore val = 0.618, episode reward = 47.0
# training episode 97 of 250 complete,  explore val = 0.615, episode reward = 43.0
# training episode 98 of 250 complete,  explore val = 0.612, episode reward = 65.0
# training episode 99 of 250 complete,  explore val = 0.609, episode reward = 80.0
# training episode 100 of 250 complete,  explore val = 0.606, episode reward = 12.0
# training episode 101 of 250 complete,  explore val = 0.603, episode reward = 97.0
# training episode 102 of 250 complete,  explore val = 0.6, episode reward = 19.0
# training episode 103 of 250 complete,  explore val = 0.597, episode reward = 180.0
# training episode 104 of 250 complete,  explore val = 0.594, episode reward = 200.0
# training episode 105 of 250 complete,  explore val = 0.591, episode reward = 216.0
# training episode 106 of 250 complete,  explore val = 0.588, episode reward = 126.0
# training episode 107 of 250 complete,  explore val = 0.585, episode reward = 13.0
# training episode 108 of 250 complete,  explore val = 0.582, episode reward = 13.0
# training episode 109 of 250 complete,  explore val = 0.579, episode reward = 101.0
# training episode 110 of 250 complete,  explore val = 0.576, episode reward = 208.0
# training episode 111 of 250 complete,  explore val = 0.573, episode reward = 90.0
# training episode 112 of 250 complete,  explore val = 0.57, episode reward = 13.0
# training episode 113 of 250 complete,  explore val = 0.568, episode reward = 18.0
# training episode 114 of 250 complete,  explore val = 0.565, episode reward = 15.0
# training episode 115 of 250 complete,  explore val = 0.562, episode reward = 27.0
# training episode 116 of 250 complete,  explore val = 0.559, episode reward = 68.0
# training episode 117 of 250 complete,  explore val = 0.556, episode reward = 119.0
# training episode 118 of 250 complete,  explore val = 0.554, episode reward = 228.0
# training episode 119 of 250 complete,  explore val = 0.551, episode reward = 33.0
# training episode 120 of 250 complete,  explore val = 0.548, episode reward = 76.0
# training episode 121 of 250 complete,  explore val = 0.545, episode reward = 19.0
# training episode 122 of 250 complete,  explore val = 0.543, episode reward = 185.0
# training episode 123 of 250 complete,  explore val = 0.54, episode reward = 34.0
# training episode 124 of 250 complete,  explore val = 0.537, episode reward = 153.0
# training episode 125 of 250 complete,  explore val = 0.534, episode reward = 500.0
# training episode 126 of 250 complete,  explore val = 0.532, episode reward = 12.0
# training episode 127 of 250 complete,  explore val = 0.529, episode reward = 500.0
# training episode 128 of 250 complete,  explore val = 0.526, episode reward = 108.0
# training episode 129 of 250 complete,  explore val = 0.524, episode reward = 60.0
# training episode 130 of 250 complete,  explore val = 0.521, episode reward = 21.0
# training episode 131 of 250 complete,  explore val = 0.519, episode reward = 16.0
# training episode 132 of 250 complete,  explore val = 0.516, episode reward = 27.0
# training episode 133 of 250 complete,  explore val = 0.513, episode reward = 11.0
# training episode 134 of 250 complete,  explore val = 0.511, episode reward = 14.0
# training episode 135 of 250 complete,  explore val = 0.508, episode reward = 41.0
# training episode 136 of 250 complete,  explore val = 0.506, episode reward = 117.0
# training episode 137 of 250 complete,  explore val = 0.503, episode reward = 95.0
# training episode 138 of 250 complete,  explore val = 0.501, episode reward = 51.0
# training episode 139 of 250 complete,  explore val = 0.498, episode reward = 18.0
# training episode 140 of 250 complete,  explore val = 0.496, episode reward = 308.0
# training episode 141 of 250 complete,  explore val = 0.493, episode reward = 282.0
# training episode 142 of 250 complete,  explore val = 0.491, episode reward = 177.0
# training episode 143 of 250 complete,  explore val = 0.488, episode reward = 349.0
# training episode 144 of 250 complete,  explore val = 0.486, episode reward = 500.0
# training episode 145 of 250 complete,  explore val = 0.483, episode reward = 31.0
# training episode 146 of 250 complete,  explore val = 0.481, episode reward = 115.0
# training episode 147 of 250 complete,  explore val = 0.479, episode reward = 214.0
# training episode 148 of 250 complete,  explore val = 0.476, episode reward = 44.0
# training episode 149 of 250 complete,  explore val = 0.474, episode reward = 126.0
# training episode 150 of 250 complete,  explore val = 0.471, episode reward = 123.0
# training episode 151 of 250 complete,  explore val = 0.469, episode reward = 61.0
# training episode 152 of 250 complete,  explore val = 0.467, episode reward = 278.0
# training episode 153 of 250 complete,  explore val = 0.464, episode reward = 62.0
# training episode 154 of 250 complete,  explore val = 0.462, episode reward = 238.0
# training episode 155 of 250 complete,  explore val = 0.46, episode reward = 26.0
# training episode 156 of 250 complete,  explore val = 0.458, episode reward = 9.0
# training episode 157 of 250 complete,  explore val = 0.455, episode reward = 12.0
# training episode 158 of 250 complete,  explore val = 0.453, episode reward = 13.0
# training episode 159 of 250 complete,  explore val = 0.451, episode reward = 15.0
# training episode 160 of 250 complete,  explore val = 0.448, episode reward = 11.0
# training episode 161 of 250 complete,  explore val = 0.446, episode reward = 167.0
# training episode 162 of 250 complete,  explore val = 0.444, episode reward = 428.0
# training episode 163 of 250 complete,  explore val = 0.442, episode reward = 500.0
# training episode 164 of 250 complete,  explore val = 0.44, episode reward = 500.0
# training episode 165 of 250 complete,  explore val = 0.437, episode reward = 43.0
# training episode 166 of 250 complete,  explore val = 0.435, episode reward = 290.0
# training episode 167 of 250 complete,  explore val = 0.433, episode reward = 11.0
# training episode 168 of 250 complete,  explore val = 0.431, episode reward = 9.0
# training episode 169 of 250 complete,  explore val = 0.429, episode reward = 12.0
# training episode 170 of 250 complete,  explore val = 0.427, episode reward = 10.0
# training episode 171 of 250 complete,  explore val = 0.424, episode reward = 15.0
# training episode 172 of 250 complete,  explore val = 0.422, episode reward = 9.0
# training episode 173 of 250 complete,  explore val = 0.42, episode reward = 10.0
# training episode 174 of 250 complete,  explore val = 0.418, episode reward = 13.0
# training episode 175 of 250 complete,  explore val = 0.416, episode reward = 284.0
# training episode 176 of 250 complete,  explore val = 0.414, episode reward = 500.0
# training episode 177 of 250 complete,  explore val = 0.412, episode reward = 500.0
# training episode 178 of 250 complete,  explore val = 0.41, episode reward = 192.0
# training episode 179 of 250 complete,  explore val = 0.408, episode reward = 213.0
# training episode 180 of 250 complete,  explore val = 0.406, episode reward = 451.0
# training episode 181 of 250 complete,  explore val = 0.404, episode reward = 53.0
# training episode 182 of 250 complete,  explore val = 0.402, episode reward = 273.0
# training episode 183 of 250 complete,  explore val = 0.4, episode reward = 190.0
# training episode 184 of 250 complete,  explore val = 0.398, episode reward = 288.0
# training episode 185 of 250 complete,  explore val = 0.396, episode reward = 16.0
# training episode 186 of 250 complete,  explore val = 0.394, episode reward = 500.0
# training episode 187 of 250 complete,  explore val = 0.392, episode reward = 24.0
# training episode 188 of 250 complete,  explore val = 0.39, episode reward = 500.0
# training episode 189 of 250 complete,  explore val = 0.388, episode reward = 42.0
# training episode 190 of 250 complete,  explore val = 0.386, episode reward = 14.0
# training episode 191 of 250 complete,  explore val = 0.384, episode reward = 500.0
# training episode 192 of 250 complete,  explore val = 0.382, episode reward = 500.0
# training episode 193 of 250 complete,  explore val = 0.38, episode reward = 420.0
# training episode 194 of 250 complete,  explore val = 0.378, episode reward = 41.0
# training episode 195 of 250 complete,  explore val = 0.376, episode reward = 17.0
# training episode 196 of 250 complete,  explore val = 0.374, episode reward = 11.0
# training episode 197 of 250 complete,  explore val = 0.373, episode reward = 13.0
# training episode 198 of 250 complete,  explore val = 0.371, episode reward = 14.0
# training episode 199 of 250 complete,  explore val = 0.369, episode reward = 12.0
# training episode 200 of 250 complete,  explore val = 0.367, episode reward = 11.0
# training episode 201 of 250 complete,  explore val = 0.365, episode reward = 25.0
# training episode 202 of 250 complete,  explore val = 0.363, episode reward = 10.0
# training episode 203 of 250 complete,  explore val = 0.361, episode reward = 8.0
# training episode 204 of 250 complete,  explore val = 0.36, episode reward = 9.0
# training episode 205 of 250 complete,  explore val = 0.358, episode reward = 12.0
# training episode 206 of 250 complete,  explore val = 0.356, episode reward = 38.0
# training episode 207 of 250 complete,  explore val = 0.354, episode reward = 26.0
# training episode 208 of 250 complete,  explore val = 0.353, episode reward = 12.0
# training episode 209 of 250 complete,  explore val = 0.351, episode reward = 10.0
# training episode 210 of 250 complete,  explore val = 0.349, episode reward = 11.0
# training episode 211 of 250 complete,  explore val = 0.347, episode reward = 11.0
# training episode 212 of 250 complete,  explore val = 0.346, episode reward = 14.0
# training episode 213 of 250 complete,  explore val = 0.344, episode reward = 10.0
# training episode 214 of 250 complete,  explore val = 0.342, episode reward = 10.0
# training episode 215 of 250 complete,  explore val = 0.34, episode reward = 15.0
# training episode 216 of 250 complete,  explore val = 0.339, episode reward = 11.0
# training episode 217 of 250 complete,  explore val = 0.337, episode reward = 9.0
# training episode 218 of 250 complete,  explore val = 0.335, episode reward = 11.0
# training episode 219 of 250 complete,  explore val = 0.334, episode reward = 24.0
# training episode 220 of 250 complete,  explore val = 0.332, episode reward = 16.0
# training episode 221 of 250 complete,  explore val = 0.33, episode reward = 25.0
# training episode 222 of 250 complete,  explore val = 0.329, episode reward = 500.0
# training episode 223 of 250 complete,  explore val = 0.327, episode reward = 114.0
# training episode 224 of 250 complete,  explore val = 0.325, episode reward = 500.0
# training episode 225 of 250 complete,  explore val = 0.324, episode reward = 500.0
# training episode 226 of 250 complete,  explore val = 0.322, episode reward = 500.0
# training episode 227 of 250 complete,  explore val = 0.321, episode reward = 500.0
# training episode 228 of 250 complete,  explore val = 0.319, episode reward = 500.0
# training episode 229 of 250 complete,  explore val = 0.317, episode reward = 32.0
# training episode 230 of 250 complete,  explore val = 0.316, episode reward = 500.0
# training episode 231 of 250 complete,  explore val = 0.314, episode reward = 158.0
# training episode 232 of 250 complete,  explore val = 0.313, episode reward = 30.0
# training episode 233 of 250 complete,  explore val = 0.311, episode reward = 500.0
# training episode 234 of 250 complete,  explore val = 0.309, episode reward = 500.0
# training episode 235 of 250 complete,  explore val = 0.308, episode reward = 500.0
# training episode 236 of 250 complete,  explore val = 0.306, episode reward = 183.0
# training episode 237 of 250 complete,  explore val = 0.305, episode reward = 45.0
# training episode 238 of 250 complete,  explore val = 0.303, episode reward = 12.0
# training episode 239 of 250 complete,  explore val = 0.302, episode reward = 9.0
# training episode 240 of 250 complete,  explore val = 0.3, episode reward = 12.0
# training episode 241 of 250 complete,  explore val = 0.299, episode reward = 11.0
# training episode 242 of 250 complete,  explore val = 0.297, episode reward = 8.0
# training episode 243 of 250 complete,  explore val = 0.296, episode reward = 12.0
# training episode 244 of 250 complete,  explore val = 0.294, episode reward = 10.0
# training episode 245 of 250 complete,  explore val = 0.293, episode reward = 11.0
# training episode 246 of 250 complete,  explore val = 0.291, episode reward = 10.0
# training episode 247 of 250 complete,  explore val = 0.29, episode reward = 8.0
# training episode 248 of 250 complete,  explore val = 0.288, episode reward = 8.0
# training episode 249 of 250 complete,  explore val = 0.287, episode reward = 10.0
# training episode 250 of 250 complete,  explore val = 0.286, episode reward = 11.0
# q-learning algorithm complete

# %% [markdown]
# # plot total episode reward history

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_reward_history(logname,**kwargs):
    # load in total episode reward history
    data = np.loadtxt(logname)
    ave = [data[v] for v in range(100)]
    
    for i in range(0,np.size(data)-100):
        m = np.mean(data[i:i+100])
        ave.append(m)
    
    # create figure
    fig = plt.figure(figsize = (12,8))
    ax1 = fig.add_subplot(2,1,1)
    ax2 = fig.add_subplot(2,1,2)

    # plot total reward history
    start = 0
    if 'start' in kwargs:
        start = kwargs['start']
    ax1.plot(data[start:])
    ax1.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax1.set_ylabel('total reward',fontsize = 13)
    
    ax2.plot(ave[start:],linewidth=3)
    ax2.set_xlabel('episode',labelpad = 8,fontsize = 13)
    ax2.set_ylabel('ave total reward',fontsize=13)
    plt.show()

# %%
reward_logname = 'reward_logs/' + savename + '.txt'
plot_reward_history(reward_logname)
